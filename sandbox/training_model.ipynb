# %%
import training_model
import training_configs
import matplotlib.pyplot as plt
import models
config= training_configs.efficientNetB2_config
model = models.factory(config)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 256, 256, 3)  0           ['input_1[0][0]']
#
#  normalization (Normalization)  (None, 256, 256, 3)  7           ['rescaling[0][0]']
#
#  tf.math.truediv (TFOpLambda)   (None, 256, 256, 3)  0           ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 257, 257, 3)  0           ['tf.math.truediv[0][0]']
#
#  stem_conv (Conv2D)             (None, 128, 128, 32  864         ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 128, 128, 32  128         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 128, 128, 32  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_dwconv (DepthwiseConv2  (None, 128, 128, 32  288        ['stem_activation[0][0]']
#  D)                             )
#
#  block1a_bn (BatchNormalization  (None, 128, 128, 32  128        ['block1a_dwconv[0][0]']
#  )                              )
#
#  block1a_activation (Activation  (None, 128, 128, 32  0          ['block1a_bn[0][0]']
#  )                              )
#
#  block1a_se_squeeze (GlobalAver  (None, 32)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 128, 128, 32  0           ['block1a_activation[0][0]',
#                                 )                                 'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 128, 128, 16  512         ['block1a_se_excite[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 128, 128, 16  64         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1b_dwconv (DepthwiseConv2  (None, 128, 128, 16  144        ['block1a_project_bn[0][0]']
#  D)                             )
#
#  block1b_bn (BatchNormalization  (None, 128, 128, 16  64         ['block1b_dwconv[0][0]']
#  )                              )
#
#  block1b_activation (Activation  (None, 128, 128, 16  0          ['block1b_bn[0][0]']
#  )                              )
#
#  block1b_se_squeeze (GlobalAver  (None, 16)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 16)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 4)      68          ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 16)     80          ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 128, 128, 16  0           ['block1b_activation[0][0]',
#                                 )                                 'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 128, 128, 16  256         ['block1b_se_excite[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 128, 128, 16  64         ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_drop (Dropout)         (None, 128, 128, 16  0           ['block1b_project_bn[0][0]']
#                                 )
#
#  block1b_add (Add)              (None, 128, 128, 16  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_project_bn[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 128, 128, 96  1536        ['block1b_add[0][0]']
#                                 )
#
#  block2a_expand_bn (BatchNormal  (None, 128, 128, 96  384        ['block2a_expand_conv[0][0]']
#  ization)                       )
#
#  block2a_expand_activation (Act  (None, 128, 128, 96  0          ['block2a_expand_bn[0][0]']
#  ivation)                       )
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 129, 129, 96  0          ['block2a_expand_activation[0][0]
#  g2D)                           )                                ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 64, 64, 96)  864         ['block2a_dwconv_pad[0][0]']
#  D)
#
#  block2a_bn (BatchNormalization  (None, 64, 64, 96)  384         ['block2a_dwconv[0][0]']
#  )
#
#  block2a_activation (Activation  (None, 64, 64, 96)  0           ['block2a_bn[0][0]']
#  )
#
#  block2a_se_squeeze (GlobalAver  (None, 96)          0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 96)     0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 4)      388         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 96)     480         ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 64, 64, 96)   0           ['block2a_activation[0][0]',
#                                                                   'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 64, 64, 24)   2304        ['block2a_se_excite[0][0]']
#
#  block2a_project_bn (BatchNorma  (None, 64, 64, 24)  96          ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 64, 64, 144)  3456        ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 64, 64, 144)  576        ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 64, 64, 144)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_dwconv (DepthwiseConv2  (None, 64, 64, 144)  1296       ['block2b_expand_activation[0][0]
#  D)                                                              ']
#
#  block2b_bn (BatchNormalization  (None, 64, 64, 144)  576        ['block2b_dwconv[0][0]']
#  )
#
#  block2b_activation (Activation  (None, 64, 64, 144)  0          ['block2b_bn[0][0]']
#  )
#
#  block2b_se_squeeze (GlobalAver  (None, 144)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 64, 64, 144)  0           ['block2b_activation[0][0]',
#                                                                   'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 64, 64, 24)   3456        ['block2b_se_excite[0][0]']
#
#  block2b_project_bn (BatchNorma  (None, 64, 64, 24)  96          ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 64, 64, 24)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 64, 64, 24)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 64, 64, 144)  3456        ['block2b_add[0][0]']
#
#  block2c_expand_bn (BatchNormal  (None, 64, 64, 144)  576        ['block2c_expand_conv[0][0]']
#  ization)
#
#  block2c_expand_activation (Act  (None, 64, 64, 144)  0          ['block2c_expand_bn[0][0]']
#  ivation)
#
#  block2c_dwconv (DepthwiseConv2  (None, 64, 64, 144)  1296       ['block2c_expand_activation[0][0]
#  D)                                                              ']
#
#  block2c_bn (BatchNormalization  (None, 64, 64, 144)  576        ['block2c_dwconv[0][0]']
#  )
#
#  block2c_activation (Activation  (None, 64, 64, 144)  0          ['block2c_bn[0][0]']
#  )
#
#  block2c_se_squeeze (GlobalAver  (None, 144)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 64, 64, 144)  0           ['block2c_activation[0][0]',
#                                                                   'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 64, 64, 24)   3456        ['block2c_se_excite[0][0]']
#
#  block2c_project_bn (BatchNorma  (None, 64, 64, 24)  96          ['block2c_project_conv[0][0]']
#  lization)
#
#  block2c_drop (Dropout)         (None, 64, 64, 24)   0           ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)              (None, 64, 64, 24)   0           ['block2c_drop[0][0]',
#                                                                   'block2b_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 64, 64, 144)  3456        ['block2c_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 64, 64, 144)  576        ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 64, 64, 144)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 67, 67, 144)  0          ['block3a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 32, 32, 144)  3600       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 32, 32, 144)  576        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 32, 32, 144)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 144)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 32, 32, 144)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 32, 32, 48)   6912        ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 32, 32, 48)  192         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 32, 32, 288)  13824       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 32, 32, 288)  1152       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 32, 32, 288)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 32, 32, 288)  7200       ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 32, 32, 288)  1152       ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 32, 32, 288)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 288)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 32, 32, 288)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 32, 32, 48)   13824       ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 32, 32, 48)  192         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 32, 32, 48)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 32, 32, 48)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 32, 32, 288)  13824       ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 32, 32, 288)  1152       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 32, 32, 288)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_dwconv (DepthwiseConv2  (None, 32, 32, 288)  7200       ['block3c_expand_activation[0][0]
#  D)                                                              ']
#
#  block3c_bn (BatchNormalization  (None, 32, 32, 288)  1152       ['block3c_dwconv[0][0]']
#  )
#
#  block3c_activation (Activation  (None, 32, 32, 288)  0          ['block3c_bn[0][0]']
#  )
#
#  block3c_se_squeeze (GlobalAver  (None, 288)         0           ['block3c_activation[0][0]']
#  agePooling2D)
#
#  block3c_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block3c_se_squeeze[0][0]']
#
#  block3c_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multiply)   (None, 32, 32, 288)  0           ['block3c_activation[0][0]',
#                                                                   'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv2D)  (None, 32, 32, 48)   13824       ['block3c_se_excite[0][0]']
#
#  block3c_project_bn (BatchNorma  (None, 32, 32, 48)  192         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 32, 32, 48)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 32, 32, 48)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 32, 32, 288)  13824       ['block3c_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 32, 32, 288)  1152       ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 32, 32, 288)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv_pad (ZeroPaddin  (None, 33, 33, 288)  0          ['block4a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block4a_dwconv (DepthwiseConv2  (None, 16, 16, 288)  2592       ['block4a_dwconv_pad[0][0]']
#  D)
#
#  block4a_bn (BatchNormalization  (None, 16, 16, 288)  1152       ['block4a_dwconv[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 16, 16, 288)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 288)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 16, 16, 288)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 16, 16, 88)   25344       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 16, 16, 88)  352         ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 16, 16, 528)  46464       ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 16, 16, 528)  2112       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 16, 16, 528)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv (DepthwiseConv2  (None, 16, 16, 528)  4752       ['block4b_expand_activation[0][0]
#  D)                                                              ']
#
#  block4b_bn (BatchNormalization  (None, 16, 16, 528)  2112       ['block4b_dwconv[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 16, 16, 528)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 528)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 528)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 22)     11638       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 528)    12144       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 16, 16, 528)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 16, 16, 88)   46464       ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 16, 16, 88)  352         ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 16, 16, 88)   0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 16, 16, 88)   0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 16, 16, 528)  46464       ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 16, 16, 528)  2112       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 16, 16, 528)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv (DepthwiseConv2  (None, 16, 16, 528)  4752       ['block4c_expand_activation[0][0]
#  D)                                                              ']
#
#  block4c_bn (BatchNormalization  (None, 16, 16, 528)  2112       ['block4c_dwconv[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 16, 16, 528)  0          ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 528)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 528)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 22)     11638       ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 528)    12144       ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, 16, 16, 528)  0           ['block4c_activation[0][0]',
#                                                                   'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, 16, 16, 88)   46464       ['block4c_se_excite[0][0]']
#
#  block4c_project_bn (BatchNorma  (None, 16, 16, 88)  352         ['block4c_project_conv[0][0]']
#  lization)
#
#  block4c_drop (Dropout)         (None, 16, 16, 88)   0           ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)              (None, 16, 16, 88)   0           ['block4c_drop[0][0]',
#                                                                   'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2D)   (None, 16, 16, 528)  46464       ['block4c_add[0][0]']
#
#  block4d_expand_bn (BatchNormal  (None, 16, 16, 528)  2112       ['block4d_expand_conv[0][0]']
#  ization)
#
#  block4d_expand_activation (Act  (None, 16, 16, 528)  0          ['block4d_expand_bn[0][0]']
#  ivation)
#
#  block4d_dwconv (DepthwiseConv2  (None, 16, 16, 528)  4752       ['block4d_expand_activation[0][0]
#  D)                                                              ']
#
#  block4d_bn (BatchNormalization  (None, 16, 16, 528)  2112       ['block4d_dwconv[0][0]']
#  )
#
#  block4d_activation (Activation  (None, 16, 16, 528)  0          ['block4d_bn[0][0]']
#  )
#
#  block4d_se_squeeze (GlobalAver  (None, 528)         0           ['block4d_activation[0][0]']
#  agePooling2D)
#
#  block4d_se_reshape (Reshape)   (None, 1, 1, 528)    0           ['block4d_se_squeeze[0][0]']
#
#  block4d_se_reduce (Conv2D)     (None, 1, 1, 22)     11638       ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)     (None, 1, 1, 528)    12144       ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multiply)   (None, 16, 16, 528)  0           ['block4d_activation[0][0]',
#                                                                   'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv2D)  (None, 16, 16, 88)   46464       ['block4d_se_excite[0][0]']
#
#  block4d_project_bn (BatchNorma  (None, 16, 16, 88)  352         ['block4d_project_conv[0][0]']
#  lization)
#
#  block4d_drop (Dropout)         (None, 16, 16, 88)   0           ['block4d_project_bn[0][0]']
#
#  block4d_add (Add)              (None, 16, 16, 88)   0           ['block4d_drop[0][0]',
#                                                                   'block4c_add[0][0]']
#
#  block5a_expand_conv (Conv2D)   (None, 16, 16, 528)  46464       ['block4d_add[0][0]']
#
#  block5a_expand_bn (BatchNormal  (None, 16, 16, 528)  2112       ['block5a_expand_conv[0][0]']
#  ization)
#
#  block5a_expand_activation (Act  (None, 16, 16, 528)  0          ['block5a_expand_bn[0][0]']
#  ivation)
#
#  block5a_dwconv (DepthwiseConv2  (None, 16, 16, 528)  13200      ['block5a_expand_activation[0][0]
#  D)                                                              ']
#
#  block5a_bn (BatchNormalization  (None, 16, 16, 528)  2112       ['block5a_dwconv[0][0]']
#  )
#
#  block5a_activation (Activation  (None, 16, 16, 528)  0          ['block5a_bn[0][0]']
#  )
# ...
#
#  block6d_dwconv (DepthwiseConv2  (None, 8, 8, 1248)  31200       ['block6d_expand_activation[0][0]
#  D)                                                              ']
#
#  block6d_bn (BatchNormalization  (None, 8, 8, 1248)  4992        ['block6d_dwconv[0][0]']
#  )
#
#  block6d_activation (Activation  (None, 8, 8, 1248)  0           ['block6d_bn[0][0]']
#  )
#
#  block6d_se_squeeze (GlobalAver  (None, 1248)        0           ['block6d_activation[0][0]']
#  agePooling2D)
#
#  block6d_se_reshape (Reshape)   (None, 1, 1, 1248)   0           ['block6d_se_squeeze[0][0]']
#
#  block6d_se_reduce (Conv2D)     (None, 1, 1, 52)     64948       ['block6d_se_reshape[0][0]']
#
#  block6d_se_expand (Conv2D)     (None, 1, 1, 1248)   66144       ['block6d_se_reduce[0][0]']
#
#  block6d_se_excite (Multiply)   (None, 8, 8, 1248)   0           ['block6d_activation[0][0]',
#                                                                   'block6d_se_expand[0][0]']
#
#  block6d_project_conv (Conv2D)  (None, 8, 8, 208)    259584      ['block6d_se_excite[0][0]']
#
#  block6d_project_bn (BatchNorma  (None, 8, 8, 208)   832         ['block6d_project_conv[0][0]']
#  lization)
#
#  block6d_drop (Dropout)         (None, 8, 8, 208)    0           ['block6d_project_bn[0][0]']
#
#  block6d_add (Add)              (None, 8, 8, 208)    0           ['block6d_drop[0][0]',
#                                                                   'block6c_add[0][0]']
#
#  block6e_expand_conv (Conv2D)   (None, 8, 8, 1248)   259584      ['block6d_add[0][0]']
#
#  block6e_expand_bn (BatchNormal  (None, 8, 8, 1248)  4992        ['block6e_expand_conv[0][0]']
#  ization)
#
#  block6e_expand_activation (Act  (None, 8, 8, 1248)  0           ['block6e_expand_bn[0][0]']
#  ivation)
#
#  block6e_dwconv (DepthwiseConv2  (None, 8, 8, 1248)  31200       ['block6e_expand_activation[0][0]
#  D)                                                              ']
#
#  block6e_bn (BatchNormalization  (None, 8, 8, 1248)  4992        ['block6e_dwconv[0][0]']
#  )
#
#  block6e_activation (Activation  (None, 8, 8, 1248)  0           ['block6e_bn[0][0]']
#  )
#
#  block6e_se_squeeze (GlobalAver  (None, 1248)        0           ['block6e_activation[0][0]']
#  agePooling2D)
#
#  block6e_se_reshape (Reshape)   (None, 1, 1, 1248)   0           ['block6e_se_squeeze[0][0]']
#
#  block6e_se_reduce (Conv2D)     (None, 1, 1, 52)     64948       ['block6e_se_reshape[0][0]']
#
#  block6e_se_expand (Conv2D)     (None, 1, 1, 1248)   66144       ['block6e_se_reduce[0][0]']
#
#  block6e_se_excite (Multiply)   (None, 8, 8, 1248)   0           ['block6e_activation[0][0]',
#                                                                   'block6e_se_expand[0][0]']
#
#  block6e_project_conv (Conv2D)  (None, 8, 8, 208)    259584      ['block6e_se_excite[0][0]']
#
#  block6e_project_bn (BatchNorma  (None, 8, 8, 208)   832         ['block6e_project_conv[0][0]']
#  lization)
#
#  block6e_drop (Dropout)         (None, 8, 8, 208)    0           ['block6e_project_bn[0][0]']
#
#  block6e_add (Add)              (None, 8, 8, 208)    0           ['block6e_drop[0][0]',
#                                                                   'block6d_add[0][0]']
#
#  block7a_expand_conv (Conv2D)   (None, 8, 8, 1248)   259584      ['block6e_add[0][0]']
#
#  block7a_expand_bn (BatchNormal  (None, 8, 8, 1248)  4992        ['block7a_expand_conv[0][0]']
#  ization)
#
#  block7a_expand_activation (Act  (None, 8, 8, 1248)  0           ['block7a_expand_bn[0][0]']
#  ivation)
#
#  block7a_dwconv (DepthwiseConv2  (None, 8, 8, 1248)  11232       ['block7a_expand_activation[0][0]
#  D)                                                              ']
#
#  block7a_bn (BatchNormalization  (None, 8, 8, 1248)  4992        ['block7a_dwconv[0][0]']
#  )
#
#  block7a_activation (Activation  (None, 8, 8, 1248)  0           ['block7a_bn[0][0]']
#  )
#
#  block7a_se_squeeze (GlobalAver  (None, 1248)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 1248)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 52)     64948       ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 1248)   66144       ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 8, 8, 1248)   0           ['block7a_activation[0][0]',
#                                                                   'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 8, 8, 352)    439296      ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 8, 8, 352)   1408        ['block7a_project_conv[0][0]']
#  lization)
#
#  block7b_expand_conv (Conv2D)   (None, 8, 8, 2112)   743424      ['block7a_project_bn[0][0]']
#
#  block7b_expand_bn (BatchNormal  (None, 8, 8, 2112)  8448        ['block7b_expand_conv[0][0]']
#  ization)
#
#  block7b_expand_activation (Act  (None, 8, 8, 2112)  0           ['block7b_expand_bn[0][0]']
#  ivation)
#
#  block7b_dwconv (DepthwiseConv2  (None, 8, 8, 2112)  19008       ['block7b_expand_activation[0][0]
#  D)                                                              ']
#
#  block7b_bn (BatchNormalization  (None, 8, 8, 2112)  8448        ['block7b_dwconv[0][0]']
#  )
#
#  block7b_activation (Activation  (None, 8, 8, 2112)  0           ['block7b_bn[0][0]']
#  )
#
#  block7b_se_squeeze (GlobalAver  (None, 2112)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 2112)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 88)     185944      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 2112)   187968      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, 8, 8, 2112)   0           ['block7b_activation[0][0]',
#                                                                   'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 8, 8, 352)    743424      ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 8, 8, 352)   1408        ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_drop (Dropout)         (None, 8, 8, 352)    0           ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)              (None, 8, 8, 352)    0           ['block7b_drop[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#
#  top_conv (Conv2D)              (None, 8, 8, 1408)   495616      ['block7b_add[0][0]']
#
#  top_bn (BatchNormalization)    (None, 8, 8, 1408)   5632        ['top_conv[0][0]']
#
#  top_activation (Activation)    (None, 8, 8, 1408)   0           ['top_bn[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1408)        0           ['top_activation[0][0]']
#  alAveragePooling2D)
#
#  dropout (Dropout)              (None, 1408)         0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 6)            8454        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 7,777,023
# Trainable params: 7,709,448
# Non-trainable params: 67,575
# __________________________________________________________________________________________________

# %%
history=training_model.train_model(config,model)
# Out:
# Epoch 1/15
# 121/121 [==============================] - ETA: 0s - loss: 2.1462 - cohen_kappa: 0.1398
# Epoch 1: val_loss improved from inf to 5.94743, saving model to modelcheckpoints/64_4_4_0\efficientNetB2.h5
# 121/121 [==============================] - 34s 154ms/step - loss: 2.1462 - cohen_kappa: 0.1398 - val_loss: 5.9474 - val_cohen_kappa: 0.0000e+00 - lr: 0.0030
# Epoch 2/15
# 121/121 [==============================] - ETA: 0s - loss: 1.8887 - cohen_kappa: 0.2452
# Epoch 2: val_loss improved from 5.94743 to 2.26484, saving model to modelcheckpoints/64_4_4_0\efficientNetB2.h5
# 121/121 [==============================] - 17s 144ms/step - loss: 1.8887 - cohen_kappa: 0.2452 - val_loss: 2.2648 - val_cohen_kappa: 0.0000e+00 - lr: 0.0030
# Epoch 3/15
# 121/121 [==============================] - ETA: 0s - loss: 1.7859 - cohen_kappa: 0.2982
# Epoch 3: val_loss improved from 2.26484 to 2.12692, saving model to modelcheckpoints/64_4_4_0\efficientNetB2.h5
# 121/121 [==============================] - 17s 142ms/step - loss: 1.7859 - cohen_kappa: 0.2982 - val_loss: 2.1269 - val_cohen_kappa: 0.0000e+00 - lr: 0.0030
# Epoch 4/15
# 121/121 [==============================] - ETA: 0s - loss: 1.7790 - cohen_kappa: 0.3100
# Epoch 4: val_loss improved from 2.12692 to 1.79975, saving model to modelcheckpoints/64_4_4_0\efficientNetB2.h5
# 121/121 [==============================] - 17s 142ms/step - loss: 1.7790 - cohen_kappa: 0.3100 - val_loss: 1.7997 - val_cohen_kappa: -0.2273 - lr: 0.0030
# Epoch 5/15
# 121/121 [==============================] - ETA: 0s - loss: 1.7374 - cohen_kappa: 0.3394
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0009000000078231095.
#
# Epoch 5: val_loss did not improve from 1.79975
# 121/121 [==============================] - 16s 136ms/step - loss: 1.7374 - cohen_kappa: 0.3394 - val_loss: 1.9623 - val_cohen_kappa: 0.0000e+00 - lr: 0.0030
# Epoch 6/15
# 121/121 [==============================] - ETA: 0s - loss: 1.6280 - cohen_kappa: 0.4320
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00026999999536201356.
#
# Epoch 6: val_loss did not improve from 1.79975
# 121/121 [==============================] - 16s 136ms/step - loss: 1.6280 - cohen_kappa: 0.4320 - val_loss: 2.1361 - val_cohen_kappa: 0.0000e+00 - lr: 9.0000e-04
# Epoch 7/15
# 121/121 [==============================] - ETA: 0s - loss: 1.5298 - cohen_kappa: 0.5291
# Epoch 7: ReduceLROnPlateau reducing learning rate to 8.099999686237424e-05.
#
# Epoch 7: val_loss did not improve from 1.79975
# 121/121 [==============================] - 17s 137ms/step - loss: 1.5298 - cohen_kappa: 0.5291 - val_loss: 2.1331 - val_cohen_kappa: 0.0160 - lr: 2.7000e-04
# Epoch 8/15
# 121/121 [==============================] - ETA: 0s - loss: 1.4243 - cohen_kappa: 0.6125
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-05.
#
# Epoch 8: val_loss did not improve from 1.79975
# 121/121 [==============================] - 17s 138ms/step - loss: 1.4243 - cohen_kappa: 0.6125 - val_loss: 1.9104 - val_cohen_kappa: 0.1407 - lr: 8.1000e-05
# Epoch 9/15
# 121/121 [==============================] - ETA: 0s - loss: 1.3774 - cohen_kappa: 0.6261
# Epoch 9: ReduceLROnPlateau reducing learning rate to 7.289999848580919e-06.
#
# Epoch 9: val_loss did not improve from 1.79975
# 121/121 [==============================] - 17s 138ms/step - loss: 1.3774 - cohen_kappa: 0.6261 - val_loss: 1.8786 - val_cohen_kappa: 0.2930 - lr: 2.4300e-05
# Epoch 10/15
# 121/121 [==============================] - ETA: 0s - loss: 1.3732 - cohen_kappa: 0.6469
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.186999927289435e-06.
#
# Epoch 10: val_loss did not improve from 1.79975
# 121/121 [==============================] - 17s 137ms/step - loss: 1.3732 - cohen_kappa: 0.6469 - val_loss: 1.8709 - val_cohen_kappa: 0.3826 - lr: 7.2900e-06
# Epoch 11/15
# 121/121 [==============================] - ETA: 0s - loss: 1.3697 - cohen_kappa: 0.6333
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 11: val_loss did not improve from 1.79975
# 121/121 [==============================] - 17s 137ms/step - loss: 1.3697 - cohen_kappa: 0.6333 - val_loss: 1.8724 - val_cohen_kappa: 0.4001 - lr: 2.1870e-06
# Epoch 12/15
# 121/121 [==============================] - ETA: 0s - loss: 1.3696 - cohen_kappa: 0.6459
# Epoch 12: val_loss did not improve from 1.79975
# 121/121 [==============================] - 17s 138ms/step - loss: 1.3696 - cohen_kappa: 0.6459 - val_loss: 1.8640 - val_cohen_kappa: 0.4098 - lr: 1.0000e-06
# Epoch 13/15
# 121/121 [==============================] - ETA: 0s - loss: 1.3623 - cohen_kappa: 0.6586
# Epoch 13: val_loss did not improve from 1.79975
# 121/121 [==============================] - 17s 137ms/step - loss: 1.3623 - cohen_kappa: 0.6586 - val_loss: 1.8675 - val_cohen_kappa: 0.4205 - lr: 1.0000e-06
# Epoch 14/15
# 121/121 [==============================] - ETA: 0s - loss: 1.3836 - cohen_kappa: 0.6336
# Epoch 14: val_loss did not improve from 1.79975
# 121/121 [==============================] - 17s 137ms/step - loss: 1.3836 - cohen_kappa: 0.6336 - val_loss: 1.8729 - val_cohen_kappa: 0.4142 - lr: 1.0000e-06
# Epoch 15/15
# 121/121 [==============================] - ETA: 0s - loss: 1.3734 - cohen_kappa: 0.6593
# Epoch 15: val_loss did not improve from 1.79975
# 121/121 [==============================] - 17s 137ms/step - loss: 1.3734 - cohen_kappa: 0.6593 - val_loss: 1.8694 - val_cohen_kappa: 0.4187 - lr: 1.0000e-06

# %%
#  "Accuracy"
plt.plot(history.history['cohen_kappa'])
plt.plot(history.history['val_cohen_kappa'])
plt.title('model cohen kappa')
plt.ylabel('cohen kappa')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
