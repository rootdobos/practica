# %%
import training_model
import training_configs
import matplotlib.pyplot as plt
import models

# %%
config= training_configs.densenet121_config
model = models.factory(config)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 640, 640, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 646, 646, 3)  0          ['input_1[0][0]']
#
#  conv1/conv (Conv2D)            (None, 320, 320, 64  9408        ['zero_padding2d[0][0]']
#                                 )
#
#  conv1/bn (BatchNormalization)  (None, 320, 320, 64  256         ['conv1/conv[0][0]']
#                                 )
#
#  conv1/relu (Activation)        (None, 320, 320, 64  0           ['conv1/bn[0][0]']
#                                 )
#
#  zero_padding2d_1 (ZeroPadding2  (None, 322, 322, 64  0          ['conv1/relu[0][0]']
#  D)                             )
#
#  pool1 (MaxPooling2D)           (None, 160, 160, 64  0           ['zero_padding2d_1[0][0]']
#                                 )
#
#  conv2_block1_0_bn (BatchNormal  (None, 160, 160, 64  256        ['pool1[0][0]']
#  ization)                       )
#
#  conv2_block1_0_relu (Activatio  (None, 160, 160, 64  0          ['conv2_block1_0_bn[0][0]']
#  n)                             )
#
#  conv2_block1_1_conv (Conv2D)   (None, 160, 160, 12  8192        ['conv2_block1_0_relu[0][0]']
#                                 8)
#
#  conv2_block1_1_bn (BatchNormal  (None, 160, 160, 12  512        ['conv2_block1_1_conv[0][0]']
#  ization)                       8)
#
#  conv2_block1_1_relu (Activatio  (None, 160, 160, 12  0          ['conv2_block1_1_bn[0][0]']
#  n)                             8)
#
#  conv2_block1_2_conv (Conv2D)   (None, 160, 160, 32  36864       ['conv2_block1_1_relu[0][0]']
#                                 )
#
#  conv2_block1_concat (Concatena  (None, 160, 160, 96  0          ['pool1[0][0]',
#  te)                            )                                 'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 160, 160, 96  384        ['conv2_block1_concat[0][0]']
#  ization)                       )
#
#  conv2_block2_0_relu (Activatio  (None, 160, 160, 96  0          ['conv2_block2_0_bn[0][0]']
#  n)                             )
#
#  conv2_block2_1_conv (Conv2D)   (None, 160, 160, 12  12288       ['conv2_block2_0_relu[0][0]']
#                                 8)
#
#  conv2_block2_1_bn (BatchNormal  (None, 160, 160, 12  512        ['conv2_block2_1_conv[0][0]']
#  ization)                       8)
#
#  conv2_block2_1_relu (Activatio  (None, 160, 160, 12  0          ['conv2_block2_1_bn[0][0]']
#  n)                             8)
#
#  conv2_block2_2_conv (Conv2D)   (None, 160, 160, 32  36864       ['conv2_block2_1_relu[0][0]']
#                                 )
#
#  conv2_block2_concat (Concatena  (None, 160, 160, 12  0          ['conv2_block1_concat[0][0]',
#  te)                            8)                                'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 160, 160, 12  512        ['conv2_block2_concat[0][0]']
#  ization)                       8)
#
#  conv2_block3_0_relu (Activatio  (None, 160, 160, 12  0          ['conv2_block3_0_bn[0][0]']
#  n)                             8)
#
#  conv2_block3_1_conv (Conv2D)   (None, 160, 160, 12  16384       ['conv2_block3_0_relu[0][0]']
#                                 8)
#
#  conv2_block3_1_bn (BatchNormal  (None, 160, 160, 12  512        ['conv2_block3_1_conv[0][0]']
#  ization)                       8)
#
#  conv2_block3_1_relu (Activatio  (None, 160, 160, 12  0          ['conv2_block3_1_bn[0][0]']
#  n)                             8)
#
#  conv2_block3_2_conv (Conv2D)   (None, 160, 160, 32  36864       ['conv2_block3_1_relu[0][0]']
#                                 )
#
#  conv2_block3_concat (Concatena  (None, 160, 160, 16  0          ['conv2_block2_concat[0][0]',
#  te)                            0)                                'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 160, 160, 16  640        ['conv2_block3_concat[0][0]']
#  ization)                       0)
#
#  conv2_block4_0_relu (Activatio  (None, 160, 160, 16  0          ['conv2_block4_0_bn[0][0]']
#  n)                             0)
#
#  conv2_block4_1_conv (Conv2D)   (None, 160, 160, 12  20480       ['conv2_block4_0_relu[0][0]']
#                                 8)
#
#  conv2_block4_1_bn (BatchNormal  (None, 160, 160, 12  512        ['conv2_block4_1_conv[0][0]']
#  ization)                       8)
#
#  conv2_block4_1_relu (Activatio  (None, 160, 160, 12  0          ['conv2_block4_1_bn[0][0]']
#  n)                             8)
#
#  conv2_block4_2_conv (Conv2D)   (None, 160, 160, 32  36864       ['conv2_block4_1_relu[0][0]']
#                                 )
#
#  conv2_block4_concat (Concatena  (None, 160, 160, 19  0          ['conv2_block3_concat[0][0]',
#  te)                            2)                                'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 160, 160, 19  768        ['conv2_block4_concat[0][0]']
#  ization)                       2)
#
#  conv2_block5_0_relu (Activatio  (None, 160, 160, 19  0          ['conv2_block5_0_bn[0][0]']
#  n)                             2)
#
#  conv2_block5_1_conv (Conv2D)   (None, 160, 160, 12  24576       ['conv2_block5_0_relu[0][0]']
#                                 8)
#
#  conv2_block5_1_bn (BatchNormal  (None, 160, 160, 12  512        ['conv2_block5_1_conv[0][0]']
#  ization)                       8)
#
#  conv2_block5_1_relu (Activatio  (None, 160, 160, 12  0          ['conv2_block5_1_bn[0][0]']
#  n)                             8)
#
#  conv2_block5_2_conv (Conv2D)   (None, 160, 160, 32  36864       ['conv2_block5_1_relu[0][0]']
#                                 )
#
#  conv2_block5_concat (Concatena  (None, 160, 160, 22  0          ['conv2_block4_concat[0][0]',
#  te)                            4)                                'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 160, 160, 22  896        ['conv2_block5_concat[0][0]']
#  ization)                       4)
#
#  conv2_block6_0_relu (Activatio  (None, 160, 160, 22  0          ['conv2_block6_0_bn[0][0]']
#  n)                             4)
#
#  conv2_block6_1_conv (Conv2D)   (None, 160, 160, 12  28672       ['conv2_block6_0_relu[0][0]']
#                                 8)
#
#  conv2_block6_1_bn (BatchNormal  (None, 160, 160, 12  512        ['conv2_block6_1_conv[0][0]']
#  ization)                       8)
#
#  conv2_block6_1_relu (Activatio  (None, 160, 160, 12  0          ['conv2_block6_1_bn[0][0]']
#  n)                             8)
#
#  conv2_block6_2_conv (Conv2D)   (None, 160, 160, 32  36864       ['conv2_block6_1_relu[0][0]']
#                                 )
#
#  conv2_block6_concat (Concatena  (None, 160, 160, 25  0          ['conv2_block5_concat[0][0]',
#  te)                            6)                                'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 160, 160, 25  1024        ['conv2_block6_concat[0][0]']
#                                 6)
#
#  pool2_relu (Activation)        (None, 160, 160, 25  0           ['pool2_bn[0][0]']
#                                 6)
#
#  pool2_conv (Conv2D)            (None, 160, 160, 12  32768       ['pool2_relu[0][0]']
#                                 8)
#
#  pool2_pool (AveragePooling2D)  (None, 80, 80, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 80, 80, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 80, 80, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 80, 80, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 80, 80, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 80, 80, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 80, 80, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 80, 80, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 80, 80, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 80, 80, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 80, 80, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 80, 80, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 80, 80, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 80, 80, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 80, 80, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 80, 80, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 80, 80, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 80, 80, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 80, 80, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 80, 80, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 80, 80, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 80, 80, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 80, 80, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 80, 80, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 80, 80, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 80, 80, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 80, 80, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 80, 80, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 80, 80, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 80, 80, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 80, 80, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 80, 80, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 80, 80, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 80, 80, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 80, 80, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 80, 80, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 80, 80, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 80, 80, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 80, 80, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 80, 80, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 80, 80, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 80, 80, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 80, 80, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 80, 80, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 80, 80, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 80, 80, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 80, 80, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 80, 80, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 80, 80, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 80, 80, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 80, 80, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 80, 80, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 80, 80, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 80, 80, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 80, 80, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 80, 80, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 80, 80, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 80, 80, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 80, 80, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 80, 80, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 80, 80, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 80, 80, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 80, 80, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 80, 80, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 80, 80, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 80, 80, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 80, 80, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 80, 80, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 80, 80, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 80, 80, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 80, 80, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 80, 80, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 80, 80, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 80, 80, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 80, 80, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 80, 80, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 80, 80, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 80, 80, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 80, 80, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 80, 80, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 80, 80, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 80, 80, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 80, 80, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 80, 80, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 80, 80, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 80, 80, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 80, 80, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 80, 80, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 40, 40, 256)  0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 40, 40, 256)  1024       ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 40, 40, 256)  0          ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 40, 40, 128)  32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 40, 40, 128)  512        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 40, 40, 128)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 40, 40, 32)   36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 40, 40, 288)  0          ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 40, 40, 288)  1152       ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 40, 40, 288)  0          ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 40, 40, 128)  36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 40, 40, 128)  512        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 40, 40, 128)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 40, 40, 32)   36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 40, 40, 320)  0          ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 40, 40, 320)  1280       ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 40, 40, 320)  0          ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 40, 40, 128)  40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 40, 40, 128)  512        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 40, 40, 128)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 40, 40, 32)   36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 40, 40, 352)  0          ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 40, 40, 352)  1408       ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 40, 40, 352)  0          ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 40, 40, 128)  45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 40, 40, 128)  512        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 40, 40, 128)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 40, 40, 32)   36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 40, 40, 384)  0          ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 40, 40, 384)  1536       ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 40, 40, 384)  0          ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 40, 40, 128)  49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 40, 40, 128)  512        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 40, 40, 128)  0          ['conv4_block5_1_bn[0][0]']
# ...
#  conv5_block9_1_bn (BatchNormal  (None, 20, 20, 128)  512        ['conv5_block9_1_conv[0][0]']
#  ization)
#
#  conv5_block9_1_relu (Activatio  (None, 20, 20, 128)  0          ['conv5_block9_1_bn[0][0]']
#  n)
#
#  conv5_block9_2_conv (Conv2D)   (None, 20, 20, 32)   36864       ['conv5_block9_1_relu[0][0]']
#
#  conv5_block9_concat (Concatena  (None, 20, 20, 800)  0          ['conv5_block8_concat[0][0]',
#  te)                                                              'conv5_block9_2_conv[0][0]']
#
#  conv5_block10_0_bn (BatchNorma  (None, 20, 20, 800)  3200       ['conv5_block9_concat[0][0]']
#  lization)
#
#  conv5_block10_0_relu (Activati  (None, 20, 20, 800)  0          ['conv5_block10_0_bn[0][0]']
#  on)
#
#  conv5_block10_1_conv (Conv2D)  (None, 20, 20, 128)  102400      ['conv5_block10_0_relu[0][0]']
#
#  conv5_block10_1_bn (BatchNorma  (None, 20, 20, 128)  512        ['conv5_block10_1_conv[0][0]']
#  lization)
#
#  conv5_block10_1_relu (Activati  (None, 20, 20, 128)  0          ['conv5_block10_1_bn[0][0]']
#  on)
#
#  conv5_block10_2_conv (Conv2D)  (None, 20, 20, 32)   36864       ['conv5_block10_1_relu[0][0]']
#
#  conv5_block10_concat (Concaten  (None, 20, 20, 832)  0          ['conv5_block9_concat[0][0]',
#  ate)                                                             'conv5_block10_2_conv[0][0]']
#
#  conv5_block11_0_bn (BatchNorma  (None, 20, 20, 832)  3328       ['conv5_block10_concat[0][0]']
#  lization)
#
#  conv5_block11_0_relu (Activati  (None, 20, 20, 832)  0          ['conv5_block11_0_bn[0][0]']
#  on)
#
#  conv5_block11_1_conv (Conv2D)  (None, 20, 20, 128)  106496      ['conv5_block11_0_relu[0][0]']
#
#  conv5_block11_1_bn (BatchNorma  (None, 20, 20, 128)  512        ['conv5_block11_1_conv[0][0]']
#  lization)
#
#  conv5_block11_1_relu (Activati  (None, 20, 20, 128)  0          ['conv5_block11_1_bn[0][0]']
#  on)
#
#  conv5_block11_2_conv (Conv2D)  (None, 20, 20, 32)   36864       ['conv5_block11_1_relu[0][0]']
#
#  conv5_block11_concat (Concaten  (None, 20, 20, 864)  0          ['conv5_block10_concat[0][0]',
#  ate)                                                             'conv5_block11_2_conv[0][0]']
#
#  conv5_block12_0_bn (BatchNorma  (None, 20, 20, 864)  3456       ['conv5_block11_concat[0][0]']
#  lization)
#
#  conv5_block12_0_relu (Activati  (None, 20, 20, 864)  0          ['conv5_block12_0_bn[0][0]']
#  on)
#
#  conv5_block12_1_conv (Conv2D)  (None, 20, 20, 128)  110592      ['conv5_block12_0_relu[0][0]']
#
#  conv5_block12_1_bn (BatchNorma  (None, 20, 20, 128)  512        ['conv5_block12_1_conv[0][0]']
#  lization)
#
#  conv5_block12_1_relu (Activati  (None, 20, 20, 128)  0          ['conv5_block12_1_bn[0][0]']
#  on)
#
#  conv5_block12_2_conv (Conv2D)  (None, 20, 20, 32)   36864       ['conv5_block12_1_relu[0][0]']
#
#  conv5_block12_concat (Concaten  (None, 20, 20, 896)  0          ['conv5_block11_concat[0][0]',
#  ate)                                                             'conv5_block12_2_conv[0][0]']
#
#  conv5_block13_0_bn (BatchNorma  (None, 20, 20, 896)  3584       ['conv5_block12_concat[0][0]']
#  lization)
#
#  conv5_block13_0_relu (Activati  (None, 20, 20, 896)  0          ['conv5_block13_0_bn[0][0]']
#  on)
#
#  conv5_block13_1_conv (Conv2D)  (None, 20, 20, 128)  114688      ['conv5_block13_0_relu[0][0]']
#
#  conv5_block13_1_bn (BatchNorma  (None, 20, 20, 128)  512        ['conv5_block13_1_conv[0][0]']
#  lization)
#
#  conv5_block13_1_relu (Activati  (None, 20, 20, 128)  0          ['conv5_block13_1_bn[0][0]']
#  on)
#
#  conv5_block13_2_conv (Conv2D)  (None, 20, 20, 32)   36864       ['conv5_block13_1_relu[0][0]']
#
#  conv5_block13_concat (Concaten  (None, 20, 20, 928)  0          ['conv5_block12_concat[0][0]',
#  ate)                                                             'conv5_block13_2_conv[0][0]']
#
#  conv5_block14_0_bn (BatchNorma  (None, 20, 20, 928)  3712       ['conv5_block13_concat[0][0]']
#  lization)
#
#  conv5_block14_0_relu (Activati  (None, 20, 20, 928)  0          ['conv5_block14_0_bn[0][0]']
#  on)
#
#  conv5_block14_1_conv (Conv2D)  (None, 20, 20, 128)  118784      ['conv5_block14_0_relu[0][0]']
#
#  conv5_block14_1_bn (BatchNorma  (None, 20, 20, 128)  512        ['conv5_block14_1_conv[0][0]']
#  lization)
#
#  conv5_block14_1_relu (Activati  (None, 20, 20, 128)  0          ['conv5_block14_1_bn[0][0]']
#  on)
#
#  conv5_block14_2_conv (Conv2D)  (None, 20, 20, 32)   36864       ['conv5_block14_1_relu[0][0]']
#
#  conv5_block14_concat (Concaten  (None, 20, 20, 960)  0          ['conv5_block13_concat[0][0]',
#  ate)                                                             'conv5_block14_2_conv[0][0]']
#
#  conv5_block15_0_bn (BatchNorma  (None, 20, 20, 960)  3840       ['conv5_block14_concat[0][0]']
#  lization)
#
#  conv5_block15_0_relu (Activati  (None, 20, 20, 960)  0          ['conv5_block15_0_bn[0][0]']
#  on)
#
#  conv5_block15_1_conv (Conv2D)  (None, 20, 20, 128)  122880      ['conv5_block15_0_relu[0][0]']
#
#  conv5_block15_1_bn (BatchNorma  (None, 20, 20, 128)  512        ['conv5_block15_1_conv[0][0]']
#  lization)
#
#  conv5_block15_1_relu (Activati  (None, 20, 20, 128)  0          ['conv5_block15_1_bn[0][0]']
#  on)
#
#  conv5_block15_2_conv (Conv2D)  (None, 20, 20, 32)   36864       ['conv5_block15_1_relu[0][0]']
#
#  conv5_block15_concat (Concaten  (None, 20, 20, 992)  0          ['conv5_block14_concat[0][0]',
#  ate)                                                             'conv5_block15_2_conv[0][0]']
#
#  conv5_block16_0_bn (BatchNorma  (None, 20, 20, 992)  3968       ['conv5_block15_concat[0][0]']
#  lization)
#
#  conv5_block16_0_relu (Activati  (None, 20, 20, 992)  0          ['conv5_block16_0_bn[0][0]']
#  on)
#
#  conv5_block16_1_conv (Conv2D)  (None, 20, 20, 128)  126976      ['conv5_block16_0_relu[0][0]']
#
#  conv5_block16_1_bn (BatchNorma  (None, 20, 20, 128)  512        ['conv5_block16_1_conv[0][0]']
#  lization)
#
#  conv5_block16_1_relu (Activati  (None, 20, 20, 128)  0          ['conv5_block16_1_bn[0][0]']
#  on)
#
#  conv5_block16_2_conv (Conv2D)  (None, 20, 20, 32)   36864       ['conv5_block16_1_relu[0][0]']
#
#  conv5_block16_concat (Concaten  (None, 20, 20, 1024  0          ['conv5_block15_concat[0][0]',
#  ate)                           )                                 'conv5_block16_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 20, 20, 1024  4096        ['conv5_block16_concat[0][0]']
#                                 )
#
#  relu (Activation)              (None, 20, 20, 1024  0           ['bn[0][0]']
#                                 )
#
#  global_average_pooling2d (Glob  (None, 1024)        0           ['relu[0][0]']
#  alAveragePooling2D)
#
#  dropout (Dropout)              (None, 1024)         0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 6)            6150        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 7,043,654
# Trainable params: 6,960,006
# Non-trainable params: 83,648
# __________________________________________________________________________________________________

# %%
history=training_model.train_model(config,model)
# Out:
# Epoch 1/15
# 726/726 [==============================] - ETA: 0s - loss: 2.6503 - cohen_kappa: -0.0275
# Epoch 1: val_loss improved from inf to 3.85252, saving model to modelcheckpoints/0_128_5_5_2\densenet121.h5
# 726/726 [==============================] - 170s 196ms/step - loss: 2.6503 - cohen_kappa: -0.0275 - val_loss: 3.8525 - val_cohen_kappa: -0.0687 - lr: 0.0030
# Epoch 2/15
# 726/726 [==============================] - ETA: 0s - loss: 2.3746 - cohen_kappa: 0.0266
# Epoch 2: ReduceLROnPlateau reducing learning rate to 0.0009000000078231095.
#
# Epoch 2: val_loss did not improve from 3.85252
# 726/726 [==============================] - 135s 186ms/step - loss: 2.3746 - cohen_kappa: 0.0266 - val_loss: 47.3739 - val_cohen_kappa: -0.0604 - lr: 0.0030
# Epoch 3/15
# 726/726 [==============================] - ETA: 0s - loss: 2.1462 - cohen_kappa: -0.0348
# Epoch 3: val_loss improved from 3.85252 to 1.78287, saving model to modelcheckpoints/0_128_5_5_2\densenet121.h5
# 726/726 [==============================] - 135s 186ms/step - loss: 2.1462 - cohen_kappa: -0.0348 - val_loss: 1.7829 - val_cohen_kappa: 0.0765 - lr: 9.0000e-04
# Epoch 4/15
# 726/726 [==============================] - ETA: 0s - loss: 2.0221 - cohen_kappa: 0.0064
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.00026999999536201356.
#
# Epoch 4: val_loss did not improve from 1.78287
# 726/726 [==============================] - 136s 187ms/step - loss: 2.0221 - cohen_kappa: 0.0064 - val_loss: 2.4725 - val_cohen_kappa: 0.1250 - lr: 9.0000e-04
# Epoch 5/15
# 726/726 [==============================] - ETA: 0s - loss: 1.9664 - cohen_kappa: 0.0357
# Epoch 5: ReduceLROnPlateau reducing learning rate to 8.099999686237424e-05.
#
# Epoch 5: val_loss did not improve from 1.78287
# 726/726 [==============================] - 138s 191ms/step - loss: 1.9664 - cohen_kappa: 0.0357 - val_loss: 2.0700 - val_cohen_kappa: 0.2634 - lr: 2.7000e-04
# Epoch 6/15
# 726/726 [==============================] - ETA: 0s - loss: 1.9284 - cohen_kappa: 0.0632
# Epoch 6: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-05.
#
# Epoch 6: val_loss did not improve from 1.78287
# 726/726 [==============================] - 137s 189ms/step - loss: 1.9284 - cohen_kappa: 0.0632 - val_loss: 2.4833 - val_cohen_kappa: 0.2333 - lr: 8.1000e-05
# Epoch 7/15
# 726/726 [==============================] - ETA: 0s - loss: 1.9298 - cohen_kappa: 0.1259
# Epoch 7: ReduceLROnPlateau reducing learning rate to 7.289999848580919e-06.
#
# Epoch 7: val_loss did not improve from 1.78287
# 726/726 [==============================] - 138s 190ms/step - loss: 1.9298 - cohen_kappa: 0.1259 - val_loss: 2.1016 - val_cohen_kappa: 0.2439 - lr: 2.4300e-05
# Epoch 8/15
# 726/726 [==============================] - ETA: 0s - loss: 1.9179 - cohen_kappa: 0.1394
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.186999927289435e-06.
#
# Epoch 8: val_loss did not improve from 1.78287
# 726/726 [==============================] - 136s 188ms/step - loss: 1.9179 - cohen_kappa: 0.1394 - val_loss: 2.2056 - val_cohen_kappa: 0.2044 - lr: 7.2900e-06
# Epoch 9/15
# 726/726 [==============================] - ETA: 0s - loss: 1.9110 - cohen_kappa: 0.1289
# Epoch 9: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 9: val_loss did not improve from 1.78287
# 726/726 [==============================] - 130s 179ms/step - loss: 1.9110 - cohen_kappa: 0.1289 - val_loss: 2.1162 - val_cohen_kappa: 0.2233 - lr: 2.1870e-06
# Epoch 10/15
# 726/726 [==============================] - ETA: 0s - loss: 1.9196 - cohen_kappa: 0.1012
# Epoch 10: val_loss did not improve from 1.78287
# 726/726 [==============================] - 120s 165ms/step - loss: 1.9196 - cohen_kappa: 0.1012 - val_loss: 2.1750 - val_cohen_kappa: 0.2280 - lr: 1.0000e-06
# Epoch 11/15
# 726/726 [==============================] - ETA: 0s - loss: 1.9097 - cohen_kappa: 0.1243
# Epoch 11: val_loss did not improve from 1.78287
# 726/726 [==============================] - 119s 164ms/step - loss: 1.9097 - cohen_kappa: 0.1243 - val_loss: 2.4772 - val_cohen_kappa: 0.2284 - lr: 1.0000e-06
# Epoch 12/15
# 726/726 [==============================] - ETA: 0s - loss: 1.9120 - cohen_kappa: 0.1332
# Epoch 12: val_loss did not improve from 1.78287
# 726/726 [==============================] - 119s 164ms/step - loss: 1.9120 - cohen_kappa: 0.1332 - val_loss: 2.2139 - val_cohen_kappa: 0.2294 - lr: 1.0000e-06
# Epoch 13/15
# 726/726 [==============================] - ETA: 0s - loss: 1.9314 - cohen_kappa: 0.0826
# Epoch 13: val_loss did not improve from 1.78287
# 726/726 [==============================] - 119s 164ms/step - loss: 1.9314 - cohen_kappa: 0.0826 - val_loss: 2.1413 - val_cohen_kappa: 0.1971 - lr: 1.0000e-06
# Epoch 14/15
# 726/726 [==============================] - ETA: 0s - loss: 1.8949 - cohen_kappa: 0.1257
# Epoch 14: val_loss did not improve from 1.78287
# 726/726 [==============================] - 122s 168ms/step - loss: 1.8949 - cohen_kappa: 0.1257 - val_loss: 2.3755 - val_cohen_kappa: 0.2227 - lr: 1.0000e-06
# Epoch 15/15
# 726/726 [==============================] - ETA: 0s - loss: 1.9063 - cohen_kappa: 0.1255
# Epoch 15: val_loss did not improve from 1.78287
# 726/726 [==============================] - 121s 166ms/step - loss: 1.9063 - cohen_kappa: 0.1255 - val_loss: 2.4432 - val_cohen_kappa: 0.2333 - lr: 1.0000e-06

# %%
config= training_configs.efficientNetB2_config
model = models.factory(config)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 640, 640, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 640, 640, 3)  0           ['input_1[0][0]']
#
#  normalization (Normalization)  (None, 640, 640, 3)  7           ['rescaling[0][0]']
#
#  tf.math.truediv (TFOpLambda)   (None, 640, 640, 3)  0           ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 641, 641, 3)  0           ['tf.math.truediv[0][0]']
#
#  stem_conv (Conv2D)             (None, 320, 320, 32  864         ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 320, 320, 32  128         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 320, 320, 32  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_dwconv (DepthwiseConv2  (None, 320, 320, 32  288        ['stem_activation[0][0]']
#  D)                             )
#
#  block1a_bn (BatchNormalization  (None, 320, 320, 32  128        ['block1a_dwconv[0][0]']
#  )                              )
#
#  block1a_activation (Activation  (None, 320, 320, 32  0          ['block1a_bn[0][0]']
#  )                              )
#
#  block1a_se_squeeze (GlobalAver  (None, 32)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 320, 320, 32  0           ['block1a_activation[0][0]',
#                                 )                                 'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 320, 320, 16  512         ['block1a_se_excite[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 320, 320, 16  64         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1b_dwconv (DepthwiseConv2  (None, 320, 320, 16  144        ['block1a_project_bn[0][0]']
#  D)                             )
#
#  block1b_bn (BatchNormalization  (None, 320, 320, 16  64         ['block1b_dwconv[0][0]']
#  )                              )
#
#  block1b_activation (Activation  (None, 320, 320, 16  0          ['block1b_bn[0][0]']
#  )                              )
#
#  block1b_se_squeeze (GlobalAver  (None, 16)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 16)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 4)      68          ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 16)     80          ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 320, 320, 16  0           ['block1b_activation[0][0]',
#                                 )                                 'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 320, 320, 16  256         ['block1b_se_excite[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 320, 320, 16  64         ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_drop (Dropout)         (None, 320, 320, 16  0           ['block1b_project_bn[0][0]']
#                                 )
#
#  block1b_add (Add)              (None, 320, 320, 16  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_project_bn[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 320, 320, 96  1536        ['block1b_add[0][0]']
#                                 )
#
#  block2a_expand_bn (BatchNormal  (None, 320, 320, 96  384        ['block2a_expand_conv[0][0]']
#  ization)                       )
#
#  block2a_expand_activation (Act  (None, 320, 320, 96  0          ['block2a_expand_bn[0][0]']
#  ivation)                       )
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 321, 321, 96  0          ['block2a_expand_activation[0][0]
#  g2D)                           )                                ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 160, 160, 96  864        ['block2a_dwconv_pad[0][0]']
#  D)                             )
#
#  block2a_bn (BatchNormalization  (None, 160, 160, 96  384        ['block2a_dwconv[0][0]']
#  )                              )
#
#  block2a_activation (Activation  (None, 160, 160, 96  0          ['block2a_bn[0][0]']
#  )                              )
#
#  block2a_se_squeeze (GlobalAver  (None, 96)          0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 96)     0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 4)      388         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 96)     480         ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 160, 160, 96  0           ['block2a_activation[0][0]',
#                                 )                                 'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 160, 160, 24  2304        ['block2a_se_excite[0][0]']
#                                 )
#
#  block2a_project_bn (BatchNorma  (None, 160, 160, 24  96         ['block2a_project_conv[0][0]']
#  lization)                      )
#
#  block2b_expand_conv (Conv2D)   (None, 160, 160, 14  3456        ['block2a_project_bn[0][0]']
#                                 4)
#
#  block2b_expand_bn (BatchNormal  (None, 160, 160, 14  576        ['block2b_expand_conv[0][0]']
#  ization)                       4)
#
#  block2b_expand_activation (Act  (None, 160, 160, 14  0          ['block2b_expand_bn[0][0]']
#  ivation)                       4)
#
#  block2b_dwconv (DepthwiseConv2  (None, 160, 160, 14  1296       ['block2b_expand_activation[0][0]
#  D)                             4)                               ']
#
#  block2b_bn (BatchNormalization  (None, 160, 160, 14  576        ['block2b_dwconv[0][0]']
#  )                              4)
#
#  block2b_activation (Activation  (None, 160, 160, 14  0          ['block2b_bn[0][0]']
#  )                              4)
#
#  block2b_se_squeeze (GlobalAver  (None, 144)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 160, 160, 14  0           ['block2b_activation[0][0]',
#                                 4)                                'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 160, 160, 24  3456        ['block2b_se_excite[0][0]']
#                                 )
#
#  block2b_project_bn (BatchNorma  (None, 160, 160, 24  96         ['block2b_project_conv[0][0]']
#  lization)                      )
#
#  block2b_drop (Dropout)         (None, 160, 160, 24  0           ['block2b_project_bn[0][0]']
#                                 )
#
#  block2b_add (Add)              (None, 160, 160, 24  0           ['block2b_drop[0][0]',
#                                 )                                 'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 160, 160, 14  3456        ['block2b_add[0][0]']
#                                 4)
#
#  block2c_expand_bn (BatchNormal  (None, 160, 160, 14  576        ['block2c_expand_conv[0][0]']
#  ization)                       4)
#
#  block2c_expand_activation (Act  (None, 160, 160, 14  0          ['block2c_expand_bn[0][0]']
#  ivation)                       4)
#
#  block2c_dwconv (DepthwiseConv2  (None, 160, 160, 14  1296       ['block2c_expand_activation[0][0]
#  D)                             4)                               ']
#
#  block2c_bn (BatchNormalization  (None, 160, 160, 14  576        ['block2c_dwconv[0][0]']
#  )                              4)
#
#  block2c_activation (Activation  (None, 160, 160, 14  0          ['block2c_bn[0][0]']
#  )                              4)
#
#  block2c_se_squeeze (GlobalAver  (None, 144)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 160, 160, 14  0           ['block2c_activation[0][0]',
#                                 4)                                'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 160, 160, 24  3456        ['block2c_se_excite[0][0]']
#                                 )
#
#  block2c_project_bn (BatchNorma  (None, 160, 160, 24  96         ['block2c_project_conv[0][0]']
#  lization)                      )
#
#  block2c_drop (Dropout)         (None, 160, 160, 24  0           ['block2c_project_bn[0][0]']
#                                 )
#
#  block2c_add (Add)              (None, 160, 160, 24  0           ['block2c_drop[0][0]',
#                                 )                                 'block2b_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 160, 160, 14  3456        ['block2c_add[0][0]']
#                                 4)
#
#  block3a_expand_bn (BatchNormal  (None, 160, 160, 14  576        ['block3a_expand_conv[0][0]']
#  ization)                       4)
#
#  block3a_expand_activation (Act  (None, 160, 160, 14  0          ['block3a_expand_bn[0][0]']
#  ivation)                       4)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 163, 163, 14  0          ['block3a_expand_activation[0][0]
#  g2D)                           4)                               ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 80, 80, 144)  3600       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 80, 80, 144)  576        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 80, 80, 144)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 144)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 80, 80, 144)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 80, 80, 48)   6912        ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 80, 80, 48)  192         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 80, 80, 288)  13824       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 80, 80, 288)  1152       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 80, 80, 288)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 80, 80, 288)  7200       ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 80, 80, 288)  1152       ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 80, 80, 288)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 288)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 80, 80, 288)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 80, 80, 48)   13824       ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 80, 80, 48)  192         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 80, 80, 48)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 80, 80, 48)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 80, 80, 288)  13824       ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 80, 80, 288)  1152       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 80, 80, 288)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_dwconv (DepthwiseConv2  (None, 80, 80, 288)  7200       ['block3c_expand_activation[0][0]
#  D)                                                              ']
#
#  block3c_bn (BatchNormalization  (None, 80, 80, 288)  1152       ['block3c_dwconv[0][0]']
#  )
#
#  block3c_activation (Activation  (None, 80, 80, 288)  0          ['block3c_bn[0][0]']
#  )
#
#  block3c_se_squeeze (GlobalAver  (None, 288)         0           ['block3c_activation[0][0]']
#  agePooling2D)
#
#  block3c_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block3c_se_squeeze[0][0]']
#
#  block3c_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multiply)   (None, 80, 80, 288)  0           ['block3c_activation[0][0]',
#                                                                   'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv2D)  (None, 80, 80, 48)   13824       ['block3c_se_excite[0][0]']
#
#  block3c_project_bn (BatchNorma  (None, 80, 80, 48)  192         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 80, 80, 48)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 80, 80, 48)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 80, 80, 288)  13824       ['block3c_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 80, 80, 288)  1152       ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 80, 80, 288)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv_pad (ZeroPaddin  (None, 81, 81, 288)  0          ['block4a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block4a_dwconv (DepthwiseConv2  (None, 40, 40, 288)  2592       ['block4a_dwconv_pad[0][0]']
#  D)
#
#  block4a_bn (BatchNormalization  (None, 40, 40, 288)  1152       ['block4a_dwconv[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 40, 40, 288)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 288)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 40, 40, 288)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 40, 40, 88)   25344       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 40, 40, 88)  352         ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 40, 40, 528)  46464       ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 40, 40, 528)  2112       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 40, 40, 528)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv (DepthwiseConv2  (None, 40, 40, 528)  4752       ['block4b_expand_activation[0][0]
#  D)                                                              ']
#
#  block4b_bn (BatchNormalization  (None, 40, 40, 528)  2112       ['block4b_dwconv[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 40, 40, 528)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 528)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 528)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 22)     11638       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 528)    12144       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 40, 40, 528)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 40, 40, 88)   46464       ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 40, 40, 88)  352         ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 40, 40, 88)   0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 40, 40, 88)   0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 40, 40, 528)  46464       ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 40, 40, 528)  2112       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 40, 40, 528)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv (DepthwiseConv2  (None, 40, 40, 528)  4752       ['block4c_expand_activation[0][0]
#  D)                                                              ']
#
#  block4c_bn (BatchNormalization  (None, 40, 40, 528)  2112       ['block4c_dwconv[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 40, 40, 528)  0          ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 528)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 528)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 22)     11638       ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 528)    12144       ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, 40, 40, 528)  0           ['block4c_activation[0][0]',
#                                                                   'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, 40, 40, 88)   46464       ['block4c_se_excite[0][0]']
#
#  block4c_project_bn (BatchNorma  (None, 40, 40, 88)  352         ['block4c_project_conv[0][0]']
#  lization)
#
#  block4c_drop (Dropout)         (None, 40, 40, 88)   0           ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)              (None, 40, 40, 88)   0           ['block4c_drop[0][0]',
#                                                                   'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2D)   (None, 40, 40, 528)  46464       ['block4c_add[0][0]']
#
#  block4d_expand_bn (BatchNormal  (None, 40, 40, 528)  2112       ['block4d_expand_conv[0][0]']
#  ization)
#
#  block4d_expand_activation (Act  (None, 40, 40, 528)  0          ['block4d_expand_bn[0][0]']
#  ivation)
#
#  block4d_dwconv (DepthwiseConv2  (None, 40, 40, 528)  4752       ['block4d_expand_activation[0][0]
#  D)                                                              ']
#
#  block4d_bn (BatchNormalization  (None, 40, 40, 528)  2112       ['block4d_dwconv[0][0]']
#  )
#
#  block4d_activation (Activation  (None, 40, 40, 528)  0          ['block4d_bn[0][0]']
#  )
#
#  block4d_se_squeeze (GlobalAver  (None, 528)         0           ['block4d_activation[0][0]']
#  agePooling2D)
#
#  block4d_se_reshape (Reshape)   (None, 1, 1, 528)    0           ['block4d_se_squeeze[0][0]']
#
#  block4d_se_reduce (Conv2D)     (None, 1, 1, 22)     11638       ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)     (None, 1, 1, 528)    12144       ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multiply)   (None, 40, 40, 528)  0           ['block4d_activation[0][0]',
#                                                                   'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv2D)  (None, 40, 40, 88)   46464       ['block4d_se_excite[0][0]']
#
#  block4d_project_bn (BatchNorma  (None, 40, 40, 88)  352         ['block4d_project_conv[0][0]']
#  lization)
#
#  block4d_drop (Dropout)         (None, 40, 40, 88)   0           ['block4d_project_bn[0][0]']
#
#  block4d_add (Add)              (None, 40, 40, 88)   0           ['block4d_drop[0][0]',
#                                                                   'block4c_add[0][0]']
#
#  block5a_expand_conv (Conv2D)   (None, 40, 40, 528)  46464       ['block4d_add[0][0]']
#
#  block5a_expand_bn (BatchNormal  (None, 40, 40, 528)  2112       ['block5a_expand_conv[0][0]']
#  ization)
#
#  block5a_expand_activation (Act  (None, 40, 40, 528)  0          ['block5a_expand_bn[0][0]']
#  ivation)
#
# ...
#
#  block6d_activation (Activation  (None, 20, 20, 1248  0          ['block6d_bn[0][0]']
#  )                              )
#
#  block6d_se_squeeze (GlobalAver  (None, 1248)        0           ['block6d_activation[0][0]']
#  agePooling2D)
#
#  block6d_se_reshape (Reshape)   (None, 1, 1, 1248)   0           ['block6d_se_squeeze[0][0]']
#
#  block6d_se_reduce (Conv2D)     (None, 1, 1, 52)     64948       ['block6d_se_reshape[0][0]']
#
#  block6d_se_expand (Conv2D)     (None, 1, 1, 1248)   66144       ['block6d_se_reduce[0][0]']
#
#  block6d_se_excite (Multiply)   (None, 20, 20, 1248  0           ['block6d_activation[0][0]',
#                                 )                                 'block6d_se_expand[0][0]']
#
#  block6d_project_conv (Conv2D)  (None, 20, 20, 208)  259584      ['block6d_se_excite[0][0]']
#
#  block6d_project_bn (BatchNorma  (None, 20, 20, 208)  832        ['block6d_project_conv[0][0]']
#  lization)
#
#  block6d_drop (Dropout)         (None, 20, 20, 208)  0           ['block6d_project_bn[0][0]']
#
#  block6d_add (Add)              (None, 20, 20, 208)  0           ['block6d_drop[0][0]',
#                                                                   'block6c_add[0][0]']
#
#  block6e_expand_conv (Conv2D)   (None, 20, 20, 1248  259584      ['block6d_add[0][0]']
#                                 )
#
#  block6e_expand_bn (BatchNormal  (None, 20, 20, 1248  4992       ['block6e_expand_conv[0][0]']
#  ization)                       )
#
#  block6e_expand_activation (Act  (None, 20, 20, 1248  0          ['block6e_expand_bn[0][0]']
#  ivation)                       )
#
#  block6e_dwconv (DepthwiseConv2  (None, 20, 20, 1248  31200      ['block6e_expand_activation[0][0]
#  D)                             )                                ']
#
#  block6e_bn (BatchNormalization  (None, 20, 20, 1248  4992       ['block6e_dwconv[0][0]']
#  )                              )
#
#  block6e_activation (Activation  (None, 20, 20, 1248  0          ['block6e_bn[0][0]']
#  )                              )
#
#  block6e_se_squeeze (GlobalAver  (None, 1248)        0           ['block6e_activation[0][0]']
#  agePooling2D)
#
#  block6e_se_reshape (Reshape)   (None, 1, 1, 1248)   0           ['block6e_se_squeeze[0][0]']
#
#  block6e_se_reduce (Conv2D)     (None, 1, 1, 52)     64948       ['block6e_se_reshape[0][0]']
#
#  block6e_se_expand (Conv2D)     (None, 1, 1, 1248)   66144       ['block6e_se_reduce[0][0]']
#
#  block6e_se_excite (Multiply)   (None, 20, 20, 1248  0           ['block6e_activation[0][0]',
#                                 )                                 'block6e_se_expand[0][0]']
#
#  block6e_project_conv (Conv2D)  (None, 20, 20, 208)  259584      ['block6e_se_excite[0][0]']
#
#  block6e_project_bn (BatchNorma  (None, 20, 20, 208)  832        ['block6e_project_conv[0][0]']
#  lization)
#
#  block6e_drop (Dropout)         (None, 20, 20, 208)  0           ['block6e_project_bn[0][0]']
#
#  block6e_add (Add)              (None, 20, 20, 208)  0           ['block6e_drop[0][0]',
#                                                                   'block6d_add[0][0]']
#
#  block7a_expand_conv (Conv2D)   (None, 20, 20, 1248  259584      ['block6e_add[0][0]']
#                                 )
#
#  block7a_expand_bn (BatchNormal  (None, 20, 20, 1248  4992       ['block7a_expand_conv[0][0]']
#  ization)                       )
#
#  block7a_expand_activation (Act  (None, 20, 20, 1248  0          ['block7a_expand_bn[0][0]']
#  ivation)                       )
#
#  block7a_dwconv (DepthwiseConv2  (None, 20, 20, 1248  11232      ['block7a_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7a_bn (BatchNormalization  (None, 20, 20, 1248  4992       ['block7a_dwconv[0][0]']
#  )                              )
#
#  block7a_activation (Activation  (None, 20, 20, 1248  0          ['block7a_bn[0][0]']
#  )                              )
#
#  block7a_se_squeeze (GlobalAver  (None, 1248)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 1248)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 52)     64948       ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 1248)   66144       ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 20, 20, 1248  0           ['block7a_activation[0][0]',
#                                 )                                 'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 20, 20, 352)  439296      ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 20, 20, 352)  1408       ['block7a_project_conv[0][0]']
#  lization)
#
#  block7b_expand_conv (Conv2D)   (None, 20, 20, 2112  743424      ['block7a_project_bn[0][0]']
#                                 )
#
#  block7b_expand_bn (BatchNormal  (None, 20, 20, 2112  8448       ['block7b_expand_conv[0][0]']
#  ization)                       )
#
#  block7b_expand_activation (Act  (None, 20, 20, 2112  0          ['block7b_expand_bn[0][0]']
#  ivation)                       )
#
#  block7b_dwconv (DepthwiseConv2  (None, 20, 20, 2112  19008      ['block7b_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7b_bn (BatchNormalization  (None, 20, 20, 2112  8448       ['block7b_dwconv[0][0]']
#  )                              )
#
#  block7b_activation (Activation  (None, 20, 20, 2112  0          ['block7b_bn[0][0]']
#  )                              )
#
#  block7b_se_squeeze (GlobalAver  (None, 2112)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 2112)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 88)     185944      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 2112)   187968      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, 20, 20, 2112  0           ['block7b_activation[0][0]',
#                                 )                                 'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 20, 20, 352)  743424      ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 20, 20, 352)  1408       ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_drop (Dropout)         (None, 20, 20, 352)  0           ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)              (None, 20, 20, 352)  0           ['block7b_drop[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#
#  top_conv (Conv2D)              (None, 20, 20, 1408  495616      ['block7b_add[0][0]']
#                                 )
#
#  top_bn (BatchNormalization)    (None, 20, 20, 1408  5632        ['top_conv[0][0]']
#                                 )
#
#  top_activation (Activation)    (None, 20, 20, 1408  0           ['top_bn[0][0]']
#                                 )
#
#  global_average_pooling2d (Glob  (None, 1408)        0           ['top_activation[0][0]']
#  alAveragePooling2D)
#
#  dropout (Dropout)              (None, 1408)         0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 6)            8454        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 7,777,023
# Trainable params: 7,709,448
# Non-trainable params: 67,575
# __________________________________________________________________________________________________

# %%
history1=training_model.train_model(config,model)
# Out:
# Epoch 1/15
# 726/726 [==============================] - ETA: 0s - loss: 1.9502 - cohen_kappa: 0.0128
# Epoch 1: val_loss improved from inf to 1.82792, saving model to modelcheckpoints/0_128_5_5_2\efficientNetB2.h5
# 726/726 [==============================] - 245s 305ms/step - loss: 1.9502 - cohen_kappa: 0.0128 - val_loss: 1.8279 - val_cohen_kappa: -0.0081 - lr: 0.0030
# Epoch 2/15
# 726/726 [==============================] - ETA: 0s - loss: 1.8527 - cohen_kappa: 0.0739
# Epoch 2: ReduceLROnPlateau reducing learning rate to 0.0009000000078231095.
#
# Epoch 2: val_loss did not improve from 1.82792
# 726/726 [==============================] - 215s 297ms/step - loss: 1.8527 - cohen_kappa: 0.0739 - val_loss: 1.9296 - val_cohen_kappa: -1.1921e-07 - lr: 0.0030
# Epoch 3/15
# 726/726 [==============================] - ETA: 0s - loss: 1.7808 - cohen_kappa: 0.1751
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.00026999999536201356.
#
# Epoch 3: val_loss did not improve from 1.82792
# 726/726 [==============================] - 219s 302ms/step - loss: 1.7808 - cohen_kappa: 0.1751 - val_loss: 2.0130 - val_cohen_kappa: -1.1921e-07 - lr: 9.0000e-04
# Epoch 4/15
# 726/726 [==============================] - ETA: 0s - loss: 1.7598 - cohen_kappa: 0.1964
# Epoch 4: ReduceLROnPlateau reducing learning rate to 8.099999686237424e-05.
#
# Epoch 4: val_loss did not improve from 1.82792
# 726/726 [==============================] - 218s 300ms/step - loss: 1.7598 - cohen_kappa: 0.1964 - val_loss: 2.0458 - val_cohen_kappa: -1.1921e-07 - lr: 2.7000e-04
# Epoch 5/15
# 726/726 [==============================] - ETA: 0s - loss: 1.7510 - cohen_kappa: 0.2082
# Epoch 5: val_loss improved from 1.82792 to 1.77390, saving model to modelcheckpoints/0_128_5_5_2\efficientNetB2.h5
# 726/726 [==============================] - 217s 299ms/step - loss: 1.7510 - cohen_kappa: 0.2082 - val_loss: 1.7739 - val_cohen_kappa: 0.1037 - lr: 8.1000e-05
# Epoch 6/15
# 726/726 [==============================] - ETA: 0s - loss: 1.7432 - cohen_kappa: 0.2540
# Epoch 6: val_loss improved from 1.77390 to 1.74924, saving model to modelcheckpoints/0_128_5_5_2\efficientNetB2.h5
# 726/726 [==============================] - 219s 302ms/step - loss: 1.7432 - cohen_kappa: 0.2540 - val_loss: 1.7492 - val_cohen_kappa: 0.2256 - lr: 8.1000e-05
# Epoch 7/15
# 726/726 [==============================] - ETA: 0s - loss: 1.7433 - cohen_kappa: 0.2567
# Epoch 7: val_loss improved from 1.74924 to 1.74021, saving model to modelcheckpoints/0_128_5_5_2\efficientNetB2.h5
# 726/726 [==============================] - 216s 297ms/step - loss: 1.7433 - cohen_kappa: 0.2567 - val_loss: 1.7402 - val_cohen_kappa: 0.2843 - lr: 8.1000e-05
# Epoch 8/15
# 726/726 [==============================] - ETA: 0s - loss: 1.7425 - cohen_kappa: 0.2234
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-05.
#
# Epoch 8: val_loss did not improve from 1.74021
# 726/726 [==============================] - 216s 297ms/step - loss: 1.7425 - cohen_kappa: 0.2234 - val_loss: 1.8184 - val_cohen_kappa: 0.0180 - lr: 8.1000e-05
# Epoch 9/15
# 726/726 [==============================] - ETA: 0s - loss: 1.7368 - cohen_kappa: 0.2562
# Epoch 9: val_loss improved from 1.74021 to 1.70461, saving model to modelcheckpoints/0_128_5_5_2\efficientNetB2.h5
# 726/726 [==============================] - 218s 301ms/step - loss: 1.7368 - cohen_kappa: 0.2562 - val_loss: 1.7046 - val_cohen_kappa: 0.3072 - lr: 2.4300e-05
# Epoch 10/15
# 726/726 [==============================] - ETA: 0s - loss: 1.7363 - cohen_kappa: 0.2743
# Epoch 10: ReduceLROnPlateau reducing learning rate to 7.289999848580919e-06.
#
# Epoch 10: val_loss did not improve from 1.70461
# 726/726 [==============================] - 218s 300ms/step - loss: 1.7363 - cohen_kappa: 0.2743 - val_loss: 1.7550 - val_cohen_kappa: 0.2649 - lr: 2.4300e-05
# Epoch 11/15
# 726/726 [==============================] - ETA: 0s - loss: 1.7310 - cohen_kappa: 0.2623
# Epoch 11: val_loss improved from 1.70461 to 1.69541, saving model to modelcheckpoints/0_128_5_5_2\efficientNetB2.h5
# 726/726 [==============================] - 250s 344ms/step - loss: 1.7310 - cohen_kappa: 0.2623 - val_loss: 1.6954 - val_cohen_kappa: 0.2890 - lr: 7.2900e-06
# Epoch 12/15
# 726/726 [==============================] - ETA: 0s - loss: 1.7334 - cohen_kappa: 0.2568
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.186999927289435e-06.
#
# Epoch 12: val_loss did not improve from 1.69541
# 726/726 [==============================] - 247s 340ms/step - loss: 1.7334 - cohen_kappa: 0.2568 - val_loss: 1.6967 - val_cohen_kappa: 0.3221 - lr: 7.2900e-06
# Epoch 13/15
# 726/726 [==============================] - ETA: 0s - loss: 1.7302 - cohen_kappa: 0.2779
# Epoch 13: val_loss improved from 1.69541 to 1.69335, saving model to modelcheckpoints/0_128_5_5_2\efficientNetB2.h5
# 726/726 [==============================] - 250s 344ms/step - loss: 1.7302 - cohen_kappa: 0.2779 - val_loss: 1.6934 - val_cohen_kappa: 0.3271 - lr: 2.1870e-06
# Epoch 14/15
# 726/726 [==============================] - ETA: 0s - loss: 1.7287 - cohen_kappa: 0.2877
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 14: val_loss did not improve from 1.69335
# 726/726 [==============================] - 248s 341ms/step - loss: 1.7287 - cohen_kappa: 0.2877 - val_loss: 1.6946 - val_cohen_kappa: 0.3165 - lr: 2.1870e-06
# Epoch 15/15
# 726/726 [==============================] - ETA: 0s - loss: 1.7254 - cohen_kappa: 0.2945
# Epoch 15: val_loss did not improve from 1.69335
# 726/726 [==============================] - 246s 339ms/step - loss: 1.7254 - cohen_kappa: 0.2945 - val_loss: 1.6978 - val_cohen_kappa: 0.3235 - lr: 1.0000e-06

# %%
config= training_configs.seresnext50_config
model = models.factory(config)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 640, 640, 3  0           []
#                                 )]
#
#  zero_padding2d_2 (ZeroPadding2  (None, 646, 646, 3)  0          ['input[0][0]']
#  D)
#
#  conv2d (Conv2D)                (None, 320, 320, 64  9408        ['zero_padding2d_2[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 320, 320, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 320, 320, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  zero_padding2d_3 (ZeroPadding2  (None, 322, 322, 64  0          ['activation[0][0]']
#  D)                             )
#
#  max_pooling2d (MaxPooling2D)   (None, 160, 160, 64  0           ['zero_padding2d_3[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 160, 160, 12  8192        ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_1 (BatchNo  (None, 160, 160, 12  512        ['conv2d_1[0][0]']
#  rmalization)                   8)
#
#  activation_1 (Activation)      (None, 160, 160, 12  0           ['batch_normalization_1[0][0]']
#                                 8)
#
#  zero_padding2d_4 (ZeroPadding2  (None, 162, 162, 12  0          ['activation_1[0][0]']
#  D)                             8)
#
#  lambda (Lambda)                (None, 162, 162, 4)  0           ['zero_padding2d_4[0][0]']
#
#  lambda_1 (Lambda)              (None, 162, 162, 4)  0           ['zero_padding2d_4[0][0]']
#
#  lambda_2 (Lambda)              (None, 162, 162, 4)  0           ['zero_padding2d_4[0][0]']
#
#  lambda_3 (Lambda)              (None, 162, 162, 4)  0           ['zero_padding2d_4[0][0]']
#
#  lambda_4 (Lambda)              (None, 162, 162, 4)  0           ['zero_padding2d_4[0][0]']
#
#  lambda_5 (Lambda)              (None, 162, 162, 4)  0           ['zero_padding2d_4[0][0]']
#
#  lambda_6 (Lambda)              (None, 162, 162, 4)  0           ['zero_padding2d_4[0][0]']
#
#  lambda_7 (Lambda)              (None, 162, 162, 4)  0           ['zero_padding2d_4[0][0]']
#
#  lambda_8 (Lambda)              (None, 162, 162, 4)  0           ['zero_padding2d_4[0][0]']
#
#  lambda_9 (Lambda)              (None, 162, 162, 4)  0           ['zero_padding2d_4[0][0]']
#
#  lambda_10 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_4[0][0]']
#
#  lambda_11 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_4[0][0]']
#
#  lambda_12 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_4[0][0]']
#
#  lambda_13 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_4[0][0]']
#
#  lambda_14 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_4[0][0]']
#
#  lambda_15 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_4[0][0]']
#
#  lambda_16 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_4[0][0]']
#
#  lambda_17 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_4[0][0]']
#
#  lambda_18 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_4[0][0]']
#
#  lambda_19 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_4[0][0]']
#
#  lambda_20 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_4[0][0]']
#
#  lambda_21 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_4[0][0]']
#
#  lambda_22 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_4[0][0]']
#
#  lambda_23 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_4[0][0]']
#
#  lambda_24 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_4[0][0]']
#
#  lambda_25 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_4[0][0]']
#
#  lambda_26 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_4[0][0]']
#
#  lambda_27 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_4[0][0]']
#
#  lambda_28 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_4[0][0]']
#
#  lambda_29 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_4[0][0]']
#
#  lambda_30 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_4[0][0]']
#
#  lambda_31 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_4[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 160, 160, 4)  144         ['lambda[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 160, 160, 4)  144         ['lambda_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 160, 160, 4)  144         ['lambda_2[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 160, 160, 4)  144         ['lambda_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 160, 160, 4)  144         ['lambda_4[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 160, 160, 4)  144         ['lambda_5[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 160, 160, 4)  144         ['lambda_6[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 160, 160, 4)  144         ['lambda_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_8[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_9[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_10[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_11[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_12[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_13[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_14[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_15[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_16[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_17[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_18[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_19[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_20[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_21[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_22[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_23[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_24[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_25[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_26[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_27[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_28[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_29[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_30[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_31[0][0]']
#
#  concatenate (Concatenate)      (None, 160, 160, 12  0           ['conv2d_2[0][0]',
#                                 8)                                'conv2d_3[0][0]',
#                                                                   'conv2d_4[0][0]',
#                                                                   'conv2d_5[0][0]',
#                                                                   'conv2d_6[0][0]',
#                                                                   'conv2d_7[0][0]',
#                                                                   'conv2d_8[0][0]',
#                                                                   'conv2d_9[0][0]',
#                                                                   'conv2d_10[0][0]',
#                                                                   'conv2d_11[0][0]',
#                                                                   'conv2d_12[0][0]',
#                                                                   'conv2d_13[0][0]',
#                                                                   'conv2d_14[0][0]',
#                                                                   'conv2d_15[0][0]',
#                                                                   'conv2d_16[0][0]',
#                                                                   'conv2d_17[0][0]',
#                                                                   'conv2d_18[0][0]',
#                                                                   'conv2d_19[0][0]',
#                                                                   'conv2d_20[0][0]',
#                                                                   'conv2d_21[0][0]',
#                                                                   'conv2d_22[0][0]',
#                                                                   'conv2d_23[0][0]',
#                                                                   'conv2d_24[0][0]',
#                                                                   'conv2d_25[0][0]',
#                                                                   'conv2d_26[0][0]',
#                                                                   'conv2d_27[0][0]',
#                                                                   'conv2d_28[0][0]',
#                                                                   'conv2d_29[0][0]',
#                                                                   'conv2d_30[0][0]',
#                                                                   'conv2d_31[0][0]',
#                                                                   'conv2d_32[0][0]',
#                                                                   'conv2d_33[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 160, 160, 12  512        ['concatenate[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 160, 160, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  conv2d_34 (Conv2D)             (None, 160, 160, 25  32768       ['activation_2[0][0]']
#                                 6)
#
#  batch_normalization_3 (BatchNo  (None, 160, 160, 25  1024       ['conv2d_34[0][0]']
#  rmalization)                   6)
#
#  global_average_pooling2d_1 (Gl  (None, 256)         0           ['batch_normalization_3[0][0]']
#  obalAveragePooling2D)
#
#  lambda_32 (Lambda)             (None, 1, 1, 256)    0           ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  conv2d_36 (Conv2D)             (None, 1, 1, 16)     4112        ['lambda_32[0][0]']
#
#  activation_3 (Activation)      (None, 1, 1, 16)     0           ['conv2d_36[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 1, 1, 256)    4352        ['activation_3[0][0]']
#
#  activation_4 (Activation)      (None, 1, 1, 256)    0           ['conv2d_37[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 160, 160, 25  16384       ['max_pooling2d[0][0]']
#                                 6)
#
#  multiply (Multiply)            (None, 160, 160, 25  0           ['batch_normalization_3[0][0]',
#                                 6)                                'activation_4[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 160, 160, 25  1024       ['conv2d_35[0][0]']
#  rmalization)                   6)
#
#  add (Add)                      (None, 160, 160, 25  0           ['multiply[0][0]',
#                                 6)                                'batch_normalization_4[0][0]']
#
#  activation_5 (Activation)      (None, 160, 160, 25  0           ['add[0][0]']
#                                 6)
#
#  conv2d_38 (Conv2D)             (None, 160, 160, 12  32768       ['activation_5[0][0]']
#                                 8)
#
#  batch_normalization_5 (BatchNo  (None, 160, 160, 12  512        ['conv2d_38[0][0]']
#  rmalization)                   8)
#
#  activation_6 (Activation)      (None, 160, 160, 12  0           ['batch_normalization_5[0][0]']
#                                 8)
#
#  zero_padding2d_5 (ZeroPadding2  (None, 162, 162, 12  0          ['activation_6[0][0]']
#  D)                             8)
#
#  lambda_33 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_5[0][0]']
#
#  lambda_34 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_5[0][0]']
#
#  lambda_35 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_5[0][0]']
#
#  lambda_36 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_5[0][0]']
#
#  lambda_37 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_5[0][0]']
#
#  lambda_38 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_5[0][0]']
#
#  lambda_39 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_5[0][0]']
#
#  lambda_40 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_5[0][0]']
#
#  lambda_41 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_5[0][0]']
#
#  lambda_42 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_5[0][0]']
#
#  lambda_43 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_5[0][0]']
#
#  lambda_44 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_5[0][0]']
#
#  lambda_45 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_5[0][0]']
#
#  lambda_46 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_5[0][0]']
#
#  lambda_47 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_5[0][0]']
#
#  lambda_48 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_5[0][0]']
#
#  lambda_49 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_5[0][0]']
#
#  lambda_50 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_5[0][0]']
#
#  lambda_51 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_5[0][0]']
#
#  lambda_52 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_5[0][0]']
#
#  lambda_53 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_5[0][0]']
#
#  lambda_54 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_5[0][0]']
#
#  lambda_55 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_5[0][0]']
#
#  lambda_56 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_5[0][0]']
#
#  lambda_57 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_5[0][0]']
#
#  lambda_58 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_5[0][0]']
#
#  lambda_59 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_5[0][0]']
#
#  lambda_60 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_5[0][0]']
#
#  lambda_61 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_5[0][0]']
#
#  lambda_62 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_5[0][0]']
#
#  lambda_63 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_5[0][0]']
#
#  lambda_64 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_5[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_33[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_34[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_35[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_36[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_37[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_38[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_39[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_40[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_41[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_42[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_43[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_44[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_45[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_46[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_47[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_48[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_49[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_50[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_51[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_52[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_53[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_54[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_55[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_56[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_57[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_58[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_59[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_60[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_61[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_62[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_63[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 160, 160, 4)  144         ['lambda_64[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 160, 160, 12  0           ['conv2d_39[0][0]',
#                                 8)                                'conv2d_40[0][0]',
#                                                                   'conv2d_41[0][0]',
#                                                                   'conv2d_42[0][0]',
#                                                                   'conv2d_43[0][0]',
#                                                                   'conv2d_44[0][0]',
#                                                                   'conv2d_45[0][0]',
#                                                                   'conv2d_46[0][0]',
#                                                                   'conv2d_47[0][0]',
#                                                                   'conv2d_48[0][0]',
#                                                                   'conv2d_49[0][0]',
#                                                                   'conv2d_50[0][0]',
#                                                                   'conv2d_51[0][0]',
#                                                                   'conv2d_52[0][0]',
#                                                                   'conv2d_53[0][0]',
#                                                                   'conv2d_54[0][0]',
#                                                                   'conv2d_55[0][0]',
#                                                                   'conv2d_56[0][0]',
#                                                                   'conv2d_57[0][0]',
#                                                                   'conv2d_58[0][0]',
#                                                                   'conv2d_59[0][0]',
#                                                                   'conv2d_60[0][0]',
#                                                                   'conv2d_61[0][0]',
#                                                                   'conv2d_62[0][0]',
#                                                                   'conv2d_63[0][0]',
#                                                                   'conv2d_64[0][0]',
#                                                                   'conv2d_65[0][0]',
#                                                                   'conv2d_66[0][0]',
#                                                                   'conv2d_67[0][0]',
#                                                                   'conv2d_68[0][0]',
#                                                                   'conv2d_69[0][0]',
#                                                                   'conv2d_70[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 160, 160, 12  512        ['concatenate_1[0][0]']
#  rmalization)                   8)
#
#  activation_7 (Activation)      (None, 160, 160, 12  0           ['batch_normalization_6[0][0]']
#                                 8)
#
#  conv2d_71 (Conv2D)             (None, 160, 160, 25  32768       ['activation_7[0][0]']
#                                 6)
#
#  batch_normalization_7 (BatchNo  (None, 160, 160, 25  1024       ['conv2d_71[0][0]']
#  rmalization)                   6)
#
#  global_average_pooling2d_2 (Gl  (None, 256)         0           ['batch_normalization_7[0][0]']
#  obalAveragePooling2D)
#
#  lambda_65 (Lambda)             (None, 1, 1, 256)    0           ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
#  conv2d_72 (Conv2D)             (None, 1, 1, 16)     4112        ['lambda_65[0][0]']
#
#  activation_8 (Activation)      (None, 1, 1, 16)     0           ['conv2d_72[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 1, 1, 256)    4352        ['activation_8[0][0]']
#
#  activation_9 (Activation)      (None, 1, 1, 256)    0           ['conv2d_73[0][0]']
#
#  multiply_1 (Multiply)          (None, 160, 160, 25  0           ['batch_normalization_7[0][0]',
#                                 6)                                'activation_9[0][0]']
#
#  add_1 (Add)                    (None, 160, 160, 25  0           ['multiply_1[0][0]',
#                                 6)                                'activation_5[0][0]']
#
#  activation_10 (Activation)     (None, 160, 160, 25  0           ['add_1[0][0]']
#                                 6)
#
#  conv2d_74 (Conv2D)             (None, 160, 160, 12  32768       ['activation_10[0][0]']
#                                 8)
#
#  batch_normalization_8 (BatchNo  (None, 160, 160, 12  512        ['conv2d_74[0][0]']
#  rmalization)                   8)
#
#  activation_11 (Activation)     (None, 160, 160, 12  0           ['batch_normalization_8[0][0]']
#                                 8)
#
#  zero_padding2d_6 (ZeroPadding2  (None, 162, 162, 12  0          ['activation_11[0][0]']
#  D)                             8)
#
#  lambda_66 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_6[0][0]']
#
#  lambda_67 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_6[0][0]']
#
#  lambda_68 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_6[0][0]']
#
#  lambda_69 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_6[0][0]']
#
#  lambda_70 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_6[0][0]']
#
#  lambda_71 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_6[0][0]']
#
#  lambda_72 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_6[0][0]']
#
#  lambda_73 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_6[0][0]']
#
#  lambda_74 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_6[0][0]']
#
#  lambda_75 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_6[0][0]']
#
#  lambda_76 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_6[0][0]']
#
#  lambda_77 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_6[0][0]']
#
#  lambda_78 (Lambda)             (None, 162, 162, 4)  0           ['zero_padding2d_6[0][0]']
#
# ...
#  lambda_517 (Lambda)            (None, 22, 22, 32)   0           ['zero_padding2d_19[0][0]']
#
#  lambda_518 (Lambda)            (None, 22, 22, 32)   0           ['zero_padding2d_19[0][0]']
#
#  lambda_519 (Lambda)            (None, 22, 22, 32)   0           ['zero_padding2d_19[0][0]']
#
#  lambda_520 (Lambda)            (None, 22, 22, 32)   0           ['zero_padding2d_19[0][0]']
#
#  lambda_521 (Lambda)            (None, 22, 22, 32)   0           ['zero_padding2d_19[0][0]']
#
#  lambda_522 (Lambda)            (None, 22, 22, 32)   0           ['zero_padding2d_19[0][0]']
#
#  lambda_523 (Lambda)            (None, 22, 22, 32)   0           ['zero_padding2d_19[0][0]']
#
#  lambda_524 (Lambda)            (None, 22, 22, 32)   0           ['zero_padding2d_19[0][0]']
#
#  lambda_525 (Lambda)            (None, 22, 22, 32)   0           ['zero_padding2d_19[0][0]']
#
#  lambda_526 (Lambda)            (None, 22, 22, 32)   0           ['zero_padding2d_19[0][0]']
#
#  conv2d_546 (Conv2D)            (None, 20, 20, 32)   9216        ['lambda_495[0][0]']
#
#  conv2d_547 (Conv2D)            (None, 20, 20, 32)   9216        ['lambda_496[0][0]']
#
#  conv2d_548 (Conv2D)            (None, 20, 20, 32)   9216        ['lambda_497[0][0]']
#
#  conv2d_549 (Conv2D)            (None, 20, 20, 32)   9216        ['lambda_498[0][0]']
#
#  conv2d_550 (Conv2D)            (None, 20, 20, 32)   9216        ['lambda_499[0][0]']
#
#  conv2d_551 (Conv2D)            (None, 20, 20, 32)   9216        ['lambda_500[0][0]']
#
#  conv2d_552 (Conv2D)            (None, 20, 20, 32)   9216        ['lambda_501[0][0]']
#
#  conv2d_553 (Conv2D)            (None, 20, 20, 32)   9216        ['lambda_502[0][0]']
#
#  conv2d_554 (Conv2D)            (None, 20, 20, 32)   9216        ['lambda_503[0][0]']
#
#  conv2d_555 (Conv2D)            (None, 20, 20, 32)   9216        ['lambda_504[0][0]']
#
#  conv2d_556 (Conv2D)            (None, 20, 20, 32)   9216        ['lambda_505[0][0]']
#
#  conv2d_557 (Conv2D)            (None, 20, 20, 32)   9216        ['lambda_506[0][0]']
#
#  conv2d_558 (Conv2D)            (None, 20, 20, 32)   9216        ['lambda_507[0][0]']
#
#  conv2d_559 (Conv2D)            (None, 20, 20, 32)   9216        ['lambda_508[0][0]']
#
#  conv2d_560 (Conv2D)            (None, 20, 20, 32)   9216        ['lambda_509[0][0]']
#
#  conv2d_561 (Conv2D)            (None, 20, 20, 32)   9216        ['lambda_510[0][0]']
#
#  conv2d_562 (Conv2D)            (None, 20, 20, 32)   9216        ['lambda_511[0][0]']
#
#  conv2d_563 (Conv2D)            (None, 20, 20, 32)   9216        ['lambda_512[0][0]']
#
#  conv2d_564 (Conv2D)            (None, 20, 20, 32)   9216        ['lambda_513[0][0]']
#
#  conv2d_565 (Conv2D)            (None, 20, 20, 32)   9216        ['lambda_514[0][0]']
#
#  conv2d_566 (Conv2D)            (None, 20, 20, 32)   9216        ['lambda_515[0][0]']
#
#  conv2d_567 (Conv2D)            (None, 20, 20, 32)   9216        ['lambda_516[0][0]']
#
#  conv2d_568 (Conv2D)            (None, 20, 20, 32)   9216        ['lambda_517[0][0]']
#
#  conv2d_569 (Conv2D)            (None, 20, 20, 32)   9216        ['lambda_518[0][0]']
#
#  conv2d_570 (Conv2D)            (None, 20, 20, 32)   9216        ['lambda_519[0][0]']
#
#  conv2d_571 (Conv2D)            (None, 20, 20, 32)   9216        ['lambda_520[0][0]']
#
#  conv2d_572 (Conv2D)            (None, 20, 20, 32)   9216        ['lambda_521[0][0]']
#
#  conv2d_573 (Conv2D)            (None, 20, 20, 32)   9216        ['lambda_522[0][0]']
#
#  conv2d_574 (Conv2D)            (None, 20, 20, 32)   9216        ['lambda_523[0][0]']
#
#  conv2d_575 (Conv2D)            (None, 20, 20, 32)   9216        ['lambda_524[0][0]']
#
#  conv2d_576 (Conv2D)            (None, 20, 20, 32)   9216        ['lambda_525[0][0]']
#
#  conv2d_577 (Conv2D)            (None, 20, 20, 32)   9216        ['lambda_526[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 20, 20, 1024  0           ['conv2d_546[0][0]',
#                                 )                                 'conv2d_547[0][0]',
#                                                                   'conv2d_548[0][0]',
#                                                                   'conv2d_549[0][0]',
#                                                                   'conv2d_550[0][0]',
#                                                                   'conv2d_551[0][0]',
#                                                                   'conv2d_552[0][0]',
#                                                                   'conv2d_553[0][0]',
#                                                                   'conv2d_554[0][0]',
#                                                                   'conv2d_555[0][0]',
#                                                                   'conv2d_556[0][0]',
#                                                                   'conv2d_557[0][0]',
#                                                                   'conv2d_558[0][0]',
#                                                                   'conv2d_559[0][0]',
#                                                                   'conv2d_560[0][0]',
#                                                                   'conv2d_561[0][0]',
#                                                                   'conv2d_562[0][0]',
#                                                                   'conv2d_563[0][0]',
#                                                                   'conv2d_564[0][0]',
#                                                                   'conv2d_565[0][0]',
#                                                                   'conv2d_566[0][0]',
#                                                                   'conv2d_567[0][0]',
#                                                                   'conv2d_568[0][0]',
#                                                                   'conv2d_569[0][0]',
#                                                                   'conv2d_570[0][0]',
#                                                                   'conv2d_571[0][0]',
#                                                                   'conv2d_572[0][0]',
#                                                                   'conv2d_573[0][0]',
#                                                                   'conv2d_574[0][0]',
#                                                                   'conv2d_575[0][0]',
#                                                                   'conv2d_576[0][0]',
#                                                                   'conv2d_577[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 20, 20, 1024  4096       ['concatenate_15[0][0]']
#  ormalization)                  )
#
#  activation_77 (Activation)     (None, 20, 20, 1024  0           ['batch_normalization_51[0][0]']
#                                 )
#
#  conv2d_578 (Conv2D)            (None, 20, 20, 2048  2097152     ['activation_77[0][0]']
#                                 )
#
#  batch_normalization_52 (BatchN  (None, 20, 20, 2048  8192       ['conv2d_578[0][0]']
#  ormalization)                  )
#
#  global_average_pooling2d_16 (G  (None, 2048)        0           ['batch_normalization_52[0][0]']
#  lobalAveragePooling2D)
#
#  lambda_527 (Lambda)            (None, 1, 1, 2048)   0           ['global_average_pooling2d_16[0][
#                                                                  0]']
#
#  conv2d_579 (Conv2D)            (None, 1, 1, 128)    262272      ['lambda_527[0][0]']
#
#  activation_78 (Activation)     (None, 1, 1, 128)    0           ['conv2d_579[0][0]']
#
#  conv2d_580 (Conv2D)            (None, 1, 1, 2048)   264192      ['activation_78[0][0]']
#
#  activation_79 (Activation)     (None, 1, 1, 2048)   0           ['conv2d_580[0][0]']
#
#  multiply_15 (Multiply)         (None, 20, 20, 2048  0           ['batch_normalization_52[0][0]',
#                                 )                                 'activation_79[0][0]']
#
#  add_15 (Add)                   (None, 20, 20, 2048  0           ['multiply_15[0][0]',
#                                 )                                 'activation_75[0][0]']
#
#  activation_80 (Activation)     (None, 20, 20, 2048  0           ['add_15[0][0]']
#                                 )
#
#  global_average_pooling2d_17 (G  (None, 2048)        0           ['activation_80[0][0]']
#  lobalAveragePooling2D)
#
#  dense_1 (Dense)                (None, 6)            12294       ['global_average_pooling2d_17[0][
#                                                                  0]']
#
# ==================================================================================================
# Total params: 25,591,414
# Trainable params: 25,523,190
# Non-trainable params: 68,224
# __________________________________________________________________________________________________

# %%
history2=training_model.train_model(config,model)
# Out:
# Epoch 1/15
# 726/726 [==============================] - ETA: 0s - loss: 1.8635 - cohen_kappa: 0.0372
# Epoch 1: val_loss improved from inf to 21.60075, saving model to modelcheckpoints/0_128_5_5_2\seresnext50.h5
# 726/726 [==============================] - 397s 515ms/step - loss: 1.8635 - cohen_kappa: 0.0372 - val_loss: 21.6008 - val_cohen_kappa: -0.0213 - lr: 0.0030
# Epoch 2/15
# 726/726 [==============================] - ETA: 0s - loss: 1.8336 - cohen_kappa: 0.0605
# Epoch 2: val_loss improved from 21.60075 to 6.19477, saving model to modelcheckpoints/0_128_5_5_2\seresnext50.h5
# 726/726 [==============================] - 368s 507ms/step - loss: 1.8336 - cohen_kappa: 0.0605 - val_loss: 6.1948 - val_cohen_kappa: -0.0048 - lr: 0.0030
# Epoch 3/15
# 726/726 [==============================] - ETA: 0s - loss: 1.8109 - cohen_kappa: 0.1151
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0009000000078231095.
#
# Epoch 3: val_loss did not improve from 6.19477
# 726/726 [==============================] - 367s 505ms/step - loss: 1.8109 - cohen_kappa: 0.1151 - val_loss: 25.5056 - val_cohen_kappa: 0.0375 - lr: 0.0030
# Epoch 4/15
# 726/726 [==============================] - ETA: 0s - loss: 1.7872 - cohen_kappa: 0.1264
# Epoch 4: val_loss improved from 6.19477 to 1.81636, saving model to modelcheckpoints/0_128_5_5_2\seresnext50.h5
# 726/726 [==============================] - 368s 507ms/step - loss: 1.7872 - cohen_kappa: 0.1264 - val_loss: 1.8164 - val_cohen_kappa: -0.0065 - lr: 9.0000e-04
# Epoch 5/15
# 726/726 [==============================] - ETA: 0s - loss: 1.7804 - cohen_kappa: 0.1595
# Epoch 5: val_loss improved from 1.81636 to 1.79224, saving model to modelcheckpoints/0_128_5_5_2\seresnext50.h5
# 726/726 [==============================] - 368s 507ms/step - loss: 1.7804 - cohen_kappa: 0.1595 - val_loss: 1.7922 - val_cohen_kappa: 0.0000e+00 - lr: 9.0000e-04
# Epoch 6/15
# 726/726 [==============================] - ETA: 0s - loss: 1.7828 - cohen_kappa: 0.1192
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00026999999536201356.
#
# Epoch 6: val_loss did not improve from 1.79224
# 726/726 [==============================] - 367s 506ms/step - loss: 1.7828 - cohen_kappa: 0.1192 - val_loss: 5.5105 - val_cohen_kappa: 0.2909 - lr: 9.0000e-04
# Epoch 7/15
# 726/726 [==============================] - ETA: 0s - loss: 1.7607 - cohen_kappa: 0.1912
# Epoch 7: ReduceLROnPlateau reducing learning rate to 8.099999686237424e-05.
#
# Epoch 7: val_loss did not improve from 1.79224
# 726/726 [==============================] - 365s 503ms/step - loss: 1.7607 - cohen_kappa: 0.1912 - val_loss: 2.8458 - val_cohen_kappa: 0.2800 - lr: 2.7000e-04
# Epoch 8/15
# 726/726 [==============================] - ETA: 0s - loss: 1.7470 - cohen_kappa: 0.2093
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-05.
#
# Epoch 8: val_loss did not improve from 1.79224
# 726/726 [==============================] - 347s 478ms/step - loss: 1.7470 - cohen_kappa: 0.2093 - val_loss: 2.3896 - val_cohen_kappa: 0.2804 - lr: 8.1000e-05
# Epoch 9/15
# 726/726 [==============================] - ETA: 0s - loss: 1.7357 - cohen_kappa: 0.2377
# Epoch 9: ReduceLROnPlateau reducing learning rate to 7.289999848580919e-06.
#
# Epoch 9: val_loss did not improve from 1.79224
# 726/726 [==============================] - 419s 577ms/step - loss: 1.7357 - cohen_kappa: 0.2377 - val_loss: 2.4585 - val_cohen_kappa: 0.2877 - lr: 2.4300e-05
# Epoch 10/15
# 726/726 [==============================] - ETA: 0s - loss: 1.7317 - cohen_kappa: 0.2399
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.186999927289435e-06.
#
# Epoch 10: val_loss did not improve from 1.79224
# 726/726 [==============================] - 425s 585ms/step - loss: 1.7317 - cohen_kappa: 0.2399 - val_loss: 2.6654 - val_cohen_kappa: 0.2891 - lr: 7.2900e-06
# Epoch 11/15
# 726/726 [==============================] - ETA: 0s - loss: 1.7300 - cohen_kappa: 0.2411
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 11: val_loss did not improve from 1.79224
# 726/726 [==============================] - 425s 585ms/step - loss: 1.7300 - cohen_kappa: 0.2411 - val_loss: 2.3429 - val_cohen_kappa: 0.2492 - lr: 2.1870e-06
# Epoch 12/15
# 726/726 [==============================] - ETA: 0s - loss: 1.7295 - cohen_kappa: 0.2412
# Epoch 12: val_loss did not improve from 1.79224
# 726/726 [==============================] - 425s 586ms/step - loss: 1.7295 - cohen_kappa: 0.2412 - val_loss: 2.3123 - val_cohen_kappa: 0.2763 - lr: 1.0000e-06
# Epoch 13/15
# 726/726 [==============================] - ETA: 0s - loss: 1.7294 - cohen_kappa: 0.2453
# Epoch 13: val_loss did not improve from 1.79224
# 726/726 [==============================] - 423s 582ms/step - loss: 1.7294 - cohen_kappa: 0.2453 - val_loss: 2.4905 - val_cohen_kappa: 0.2728 - lr: 1.0000e-06
# Epoch 14/15
# 726/726 [==============================] - ETA: 0s - loss: 1.7292 - cohen_kappa: 0.2405
# Epoch 14: val_loss did not improve from 1.79224
# 726/726 [==============================] - 425s 585ms/step - loss: 1.7292 - cohen_kappa: 0.2405 - val_loss: 2.6137 - val_cohen_kappa: 0.2705 - lr: 1.0000e-06
# Epoch 15/15
# 726/726 [==============================] - ETA: 0s - loss: 1.7290 - cohen_kappa: 0.2427

# %%
config= training_configs.vgg16_config
model = models.factory(config)
model.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 320, 320, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 320, 320, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 320, 320, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 160, 160, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 160, 160, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 160, 160, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 80, 80, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 80, 80, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 80, 80, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 80, 80, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 40, 40, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 40, 40, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 40, 40, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 40, 40, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 20, 20, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 20, 20, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 20, 20, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 20, 20, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 10, 10, 512)       0
#
#  global_average_pooling2d_19  (None, 512)              0
#   (GlobalAveragePooling2D)
#
#  dense_3 (Dense)             (None, 16)                8208
#
#  batch_normalization_53 (Bat  (None, 16)               64
#  chNormalization)
#
#  dense_4 (Dense)             (None, 6)                 102
#
# =================================================================
# Total params: 14,723,062
# Trainable params: 14,723,030
# Non-trainable params: 32
# _________________________________________________________________

# %%
history3=training_model.train_model(config,model)
# Out:
# Epoch 1/15
# 484/484 [==============================] - ETA: 0s - loss: 1.7996 - auc: 0.5533 - cohen_kappa: 0.0502
# Epoch 1: val_loss improved from inf to 3.88738, saving model to modelcheckpoints/64_5_5_2\vgg16.h5
# 484/484 [==============================] - 62s 122ms/step - loss: 1.7996 - auc: 0.5533 - cohen_kappa: 0.0502 - val_loss: 3.8874 - val_auc: 0.5097 - val_cohen_kappa: -0.0825 - lr: 0.0010
# Epoch 2/15
# 484/484 [==============================] - ETA: 0s - loss: 1.7711 - auc: 0.5780 - cohen_kappa: 0.1743
# Epoch 2: val_loss improved from 3.88738 to 1.81960, saving model to modelcheckpoints/64_5_5_2\vgg16.h5
# 484/484 [==============================] - 58s 120ms/step - loss: 1.7711 - auc: 0.5780 - cohen_kappa: 0.1743 - val_loss: 1.8196 - val_auc: 0.4890 - val_cohen_kappa: -0.0163 - lr: 0.0010
# Epoch 3/15
# 484/484 [==============================] - ETA: 0s - loss: 1.7623 - auc: 0.5839 - cohen_kappa: 0.1720
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
#
# Epoch 3: val_loss did not improve from 1.81960
# 484/484 [==============================] - 58s 119ms/step - loss: 1.7623 - auc: 0.5839 - cohen_kappa: 0.1720 - val_loss: 1.8717 - val_auc: 0.5017 - val_cohen_kappa: 0.0000e+00 - lr: 0.0010
# Epoch 4/15
# 484/484 [==============================] - ETA: 0s - loss: 1.7828 - auc: 0.5459 - cohen_kappa: 0.1138
# Epoch 4: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
#
# Epoch 4: val_loss did not improve from 1.81960
# 484/484 [==============================] - 58s 119ms/step - loss: 1.7828 - auc: 0.5459 - cohen_kappa: 0.1138 - val_loss: 1.8203 - val_auc: 0.4993 - val_cohen_kappa: -0.0315 - lr: 3.0000e-04
# Epoch 5/15
# 484/484 [==============================] - ETA: 0s - loss: 1.7908 - auc: 0.5246 - cohen_kappa: -0.0220
# Epoch 5: val_loss improved from 1.81960 to 1.80077, saving model to modelcheckpoints/64_5_5_2\vgg16.h5
# 484/484 [==============================] - 57s 118ms/step - loss: 1.7908 - auc: 0.5246 - cohen_kappa: -0.0220 - val_loss: 1.8008 - val_auc: 0.4972 - val_cohen_kappa: 0.0350 - lr: 9.0000e-05
# Epoch 6/15
# 484/484 [==============================] - ETA: 0s - loss: 1.7865 - auc: 0.5341 - cohen_kappa: 0.0162
# Epoch 6: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
#
# Epoch 6: val_loss did not improve from 1.80077
# 484/484 [==============================] - 57s 117ms/step - loss: 1.7865 - auc: 0.5341 - cohen_kappa: 0.0162 - val_loss: 1.8059 - val_auc: 0.5020 - val_cohen_kappa: 0.0548 - lr: 9.0000e-05
# Epoch 7/15
# 484/484 [==============================] - ETA: 0s - loss: 1.7861 - auc: 0.5351 - cohen_kappa: 0.0175
# Epoch 7: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
#
# Epoch 7: val_loss did not improve from 1.80077
# 484/484 [==============================] - 57s 118ms/step - loss: 1.7861 - auc: 0.5351 - cohen_kappa: 0.0175 - val_loss: 1.9772 - val_auc: 0.4964 - val_cohen_kappa: 0.0528 - lr: 2.7000e-05
# Epoch 8/15
# 484/484 [==============================] - ETA: 0s - loss: 1.8080 - auc: 0.4916 - cohen_kappa: -0.1039
# Epoch 8: val_loss improved from 1.80077 to 1.79153, saving model to modelcheckpoints/64_5_5_2\vgg16.h5
# 484/484 [==============================] - 57s 118ms/step - loss: 1.8080 - auc: 0.4916 - cohen_kappa: -0.1039 - val_loss: 1.7915 - val_auc: 0.5089 - val_cohen_kappa: 0.0611 - lr: 8.1000e-06
# Epoch 9/15
# 484/484 [==============================] - ETA: 0s - loss: 1.7999 - auc: 0.5061 - cohen_kappa: -0.0533
# Epoch 9: val_loss improved from 1.79153 to 1.78306, saving model to modelcheckpoints/64_5_5_2\vgg16.h5
# 484/484 [==============================] - 57s 118ms/step - loss: 1.7999 - auc: 0.5061 - cohen_kappa: -0.0533 - val_loss: 1.7831 - val_auc: 0.5361 - val_cohen_kappa: 0.0521 - lr: 8.1000e-06
# Epoch 10/15
# 484/484 [==============================] - ETA: 0s - loss: 1.7832 - auc: 0.5411 - cohen_kappa: 0.0561
# Epoch 10: val_loss improved from 1.78306 to 1.77126, saving model to modelcheckpoints/64_5_5_2\vgg16.h5
# 484/484 [==============================] - 57s 118ms/step - loss: 1.7832 - auc: 0.5411 - cohen_kappa: 0.0561 - val_loss: 1.7713 - val_auc: 0.5520 - val_cohen_kappa: 0.0713 - lr: 8.1000e-06
# Epoch 11/15
# 484/484 [==============================] - ETA: 0s - loss: 1.7733 - auc: 0.5635 - cohen_kappa: 0.1211
# Epoch 11: val_loss improved from 1.77126 to 1.76835, saving model to modelcheckpoints/64_5_5_2\vgg16.h5
# 484/484 [==============================] - 57s 118ms/step - loss: 1.7733 - auc: 0.5635 - cohen_kappa: 0.1211 - val_loss: 1.7683 - val_auc: 0.5606 - val_cohen_kappa: 0.0928 - lr: 8.1000e-06
# Epoch 12/15
# 484/484 [==============================] - ETA: 0s - loss: 1.7688 - auc: 0.5740 - cohen_kappa: 0.1613
# Epoch 12: val_loss improved from 1.76835 to 1.76586, saving model to modelcheckpoints/64_5_5_2\vgg16.h5
# 484/484 [==============================] - 57s 118ms/step - loss: 1.7688 - auc: 0.5740 - cohen_kappa: 0.1613 - val_loss: 1.7659 - val_auc: 0.5649 - val_cohen_kappa: 0.0925 - lr: 8.1000e-06
# Epoch 13/15
# 484/484 [==============================] - ETA: 0s - loss: 1.7666 - auc: 0.5797 - cohen_kappa: 0.1724
# Epoch 13: val_loss improved from 1.76586 to 1.76372, saving model to modelcheckpoints/64_5_5_2\vgg16.h5
# 484/484 [==============================] - 57s 118ms/step - loss: 1.7666 - auc: 0.5797 - cohen_kappa: 0.1724 - val_loss: 1.7637 - val_auc: 0.5742 - val_cohen_kappa: 0.1513 - lr: 8.1000e-06
# Epoch 14/15
# 484/484 [==============================] - ETA: 0s - loss: 1.7653 - auc: 0.5826 - cohen_kappa: 0.1788
# Epoch 14: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
#
# Epoch 14: val_loss did not improve from 1.76372
# 484/484 [==============================] - 57s 118ms/step - loss: 1.7653 - auc: 0.5826 - cohen_kappa: 0.1788 - val_loss: 1.7667 - val_auc: 0.5719 - val_cohen_kappa: 0.1386 - lr: 8.1000e-06
# Epoch 15/15
# 484/484 [==============================] - ETA: 0s - loss: 1.7644 - auc: 0.5859 - cohen_kappa: 0.1896
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 15: val_loss did not improve from 1.76372
# 484/484 [==============================] - 57s 118ms/step - loss: 1.7644 - auc: 0.5859 - cohen_kappa: 0.1896 - val_loss: 1.7654 - val_auc: 0.5785 - val_cohen_kappa: 0.1487 - lr: 2.4300e-06

# %%
def plot_history(history):
#  "Accuracy"
    plt.plot(history.history['cohen_kappa'])
    plt.plot(history.history['val_cohen_kappa'])
    plt.title('model cohen kappa')
    plt.ylabel('cohen kappa')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()
    # "Loss"
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()

# %%
plot_history(history)

# %%
plot_history(history1)

# %%
plot_history(history2)

# %%
plot_history(history3)
